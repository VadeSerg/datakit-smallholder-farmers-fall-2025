# %%
import pandas as pd
import numpy as np
from dotenv import load_dotenv
import os
import joblib
import duckdb
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans, HDBSCAN
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.metrics.pairwise import cosine_similarity
import umap
import nltk
import re
from sentence_transformers import SentenceTransformer

# Import from local modules
import sys
sys.path.append('../src')
import clustering_analysis
import processing_and_visualization
import importlib
importlib.reload(clustering_analysis)
importlib.reload(processing_and_visualization)

from cleaning import minimal_clean
from clustering_analysis import cluster_with_umap_hdbscan, recluster_noise, print_cluster_examples, summarize_clusters, metacluster_preview
from processing_and_visualization import quick_save_file, save_topic_files, save_question_clusters

# Download necessary NLTK resources
import nltk
nltk.download('wordnet')
nltk.download('stopwords')

# Path for 1 million English sample questions and saved results
load_dotenv()
unlabeled_path = os.getenv("DATA_UNLABELED")
unlabeled_embeddings_path = os.getenv("DATA_UNLABELED_EMBEDDINGS")
data_dir = os.getenv("DATA_DIR")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ruggb\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ruggb\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Unlabeled Questions
# Separate notebook dedicated to clustering questions without a pre-existing 'question_topic' label

# %%
# load data
questions = pd.read_parquet(unlabeled_path)

questions = questions.drop(['response_user_type', 'response_user_status',
       'response_user_country_code', 'response_user_gender',
       'response_user_dob', 'response_user_created_at', 'response_id',
       'response_user_id', 'response_language', 'response_content',
       'response_topic', 'response_sent'], axis=1)

questions.shape
# Out:
# (643148, 12)

# %%
unlabeled_df.shape
# Out:
# (643148, 17)

# %%
# Apply separate cleaning function that just normalizes spacing and removes very common "Q" boilerplate
questions['Q_basic_clean'] = questions['question_content'].apply(minimal_clean)

# %%
# Check if embeddings file exists before generating

if os.path.exists(unlabeled_embeddings_path):
    print("Embedding file exists — loading from disk.")
    data = np.load(unlabeled_embeddings_path, allow_pickle=True)
    embeddings = data["embeddings"]
    question_ids = data["question_ids"]  # shouldn't be necessary, but saved just in case of a mix-up

else:
    print("Embedding file not found — generating embeddings.")
    model = SentenceTransformer('all-MiniLM-L6-v2')

    texts = questions['Q_basic_clean'].tolist()
    question_ids = questions['question_id'].to_numpy()

    embeddings = model.encode(
        texts,
        batch_size=64,
        show_progress_bar=True
    )
# Save embeddings to disk along with question IDs in case of mixup
    np.savez_compressed(unlabeled_embeddings_path, embeddings=embeddings, question_ids=question_ids)
    print("Saved embeddings to disk.")

questions['embedding'] = list(embeddings)
# Out:
# Embedding file exists — loading from disk.

# %%
## Perform UMAP + HDBSCAN clustering
# Commented out to avoid re-running unnecessarily or acccidentally overwriting

# unlabeled_df, unlabeled_umap, unlabeled_clusterer = cluster_with_umap_hdbscan(
#     df=questions,
#     sample_size=100_000,
#     umap_params={
#         "n_neighbors": 30,
#         "n_components": 5,
#         "metric": "cosine",
#         "random_state": 42
#     },
#     hdbscan_params={
#         "min_cluster_size": 1500,
#         "min_samples": 15,
#         "metric": "euclidean"
#     }
# )
# Out:
# Finished clustering in 4285.2 seconds
# Noise ratio: 43.21%
# Clusters found: 81
# Approx. silhouette score (excluding noise): 0.625

# %%
## Saves result of large clustering to disk if not already present
# files_to_save = {
#     "unlabeled_hdbscan_model.pkl": unlabeled_clusterer,
#     "unlabeled_umap_embedding.pkl": unlabeled_umap,
#     "unlabeled_clustered_df.parquet": unlabeled_df
# }

# for filename, obj in files_to_save.items():
#     path = os.path.join(data_dir, filename)
#     if not os.path.exists(path):
#         if filename.endswith(".parquet"):
#             obj.to_parquet(path)
#         else:
#             joblib.dump(obj, path)
#         print(f"Saved {filename}")
#     else:
#         print(f"{filename} already exists. Skipping save.")
# Out:
# unlabeled_hdbscan_model.pkl already exists. Skipping save.
# unlabeled_umap_embedding.pkl already exists. Skipping save.
# unlabeled_clustered_df.parquet already exists. Skipping save.

# %%
## Runs HDBSCAN again on the noise cluster to extract more clusters
# Adjust paramaters for smaller subset of data
hdbscan_params_noise = {
    "min_cluster_size": 400,
    "min_samples": 10,
    "metric": "euclidean"
}

noise_labels_shifted, noise_clusterer = recluster_noise(
    umap_embeddings=unlabeled_umap,
    labels=unlabeled_df["cluster"].to_numpy(),
    hdbscan_params=hdbscan_params_noise
)
# Out:
# Reclustered noise points: 277924
# New noise ratio: 56.82%
# Clusters found in noise: 136

# %%
## Preview new clusters obtained from noise cluster for quick quality check

# Select only the original noise rows
noise_mask = unlabeled_df['cluster'] == -1
noise_df = unlabeled_df.loc[noise_mask, ['Q_basic_clean']].copy()

# Assign the new noise cluster labels (length matches noise_df)
noise_df['new_cluster'] = noise_labels_shifted

print_cluster_examples(noise_df, text_column='Q_basic_clean', cluster_column='new_cluster',examples_per_cluster=5)
# Out:
# --- Cluster 187 (size=10516) ---
# - what are tha advantages of dairy farming and tha considerations set during tha setup of a dairy farm?
# - What Leads Farmers Failure To Calculate Profits And Losses At The End Of The Season.
# - If Am Poor I Want To Bcome A Farmer What Can I Do
# - What are the factors to consider when setting up farm building?
# - Many people dislike farming Why is it so?
#
# --- Cluster 110 (size=5219) ---
# - WHAT IS SOIL TEXTURE?
# - HOW CAN YOU CONTROL SOILEROSION
# - WHEN SHEET EROSION OCCUR ON YOUR FARM WHAT WILL YOU DO?
# - ,which soil doesnt require too much water
# - ,do soil affect water retention
#
# --- Cluster 166 (size=2877) ---
# - Acaricides Used In Controlling Oxalis
# - where can I buy Victoria sate herbicide in mbarara
# - How iz it harmful weed'g us'g chemicals.
# - Why are some farmers use weedmaster to kill weeds?
# - WHEN I SPRAY WEEDS WITH CHEMICALS DO THEY TAKE A LONG TIME WITH OUT COMING BACK?
#
# --- Cluster 182 (size=1860) ---
# - ,whech taip of beenci is the best grow in kitale
# - S It is now rain season & weeds grow quickly, what can I use to cultivate Dhania now after germination?.
# - is it applied even in uplands?
# - Which type is best grown in cold place
# - Which type of is 2 be planted in dry Districts like Kiruhura?
#
# --- Cluster 174 (size=1626) ---
# - Where can i find market for ovacado in linja
# - market for ovacado?
# - How Long Does It Take Hass Ovacado To Mature?
# - How can i prevent Pre Matured Ovacado From Folling.
# - What is the english name of the fruit mutomoko.
#
# --- Cluster 150 (size=1490) ---
# - How Do You Treat Coccidiosis?
# - what are the signs and symptoms of coccidiosis and its treatment
# - treatment of coccidiosis
# - what is the suitable way to prevent coccidiosis
# - coccidiosis
#
# --- Cluster 112 (size=1449) ---
# - , WHAT ARE THE TOOLS USED IN FARMING?
# - namely types of garden tools used!
# - why do we maintain farm tools and equipment
# - What is the scientific term of farming using machines
# - What is draught technology as used in agriculture
#
# --- Cluster 111 (size=1382) ---
# - I patrolled my shamba and i found that the leaves are like sieve.ie they are tone by pests which i have ever seen them.what may be the problem
# - which weeds can be very poisoners in our shamba
# - How Feet/centimetres Can Dig In My Farm For The Passage Of Woter From My Shamba?
# - What size of trenches can dig, my shamba is in a slop , paths meets there.
# - who are the shamba shape up and where is their contact
#
# --- Cluster 128 (size=1376) ---
# - In which month of the year 2018 do we expect aseason to begin on.
# - WHAT ITEM CAN I DO AT THIS SEASON
# - In Transmara Which Variety can do best during this season?
# - Doris ! Should i use mult k all the year around, and what are the key benefit please?
# - Cura fluke is the best at this season
#
# --- Cluster 175 (size=1372) ---
# - What is the correct spacing for pilipili hoho?
# - What Is The Recomended Spacing For Soyabeans, Popcorn? Is It Good To Interplant Soyabeans And Popcorns?
# - spacing of how long and the type of species to consider are
# - what about the spacing?
# - spacing of sugarloaf seedlings
#
# --- Cluster 204 (size=1366) ---
# - how how old are those costing 250
# - what is the price of nambale a kg in Mbarara
# - kshs550 per piece....They are about to lay...kandara Muranga county
# - how much z kg of meat at jinja central mkt
# - how much is a crate of pilipili hoho in eldoret?
#
# --- Cluster 92 (size=1364) ---
# - How is vanilla pollinated?
# - Is vanilla harvested and sold flesh or dry?
# - Where could I find vanilla for planting
# - how long does vanilla take to mature?
# - How long does vanilla take to put seeds after planting?
#
# --- Cluster 154 (size=1361) ---
# - S x-stic of variable inputs
# - Do you sell farm inputs?
# - # How can i reduce agrofarm inputs?
# - ,what is farm inputs as far as Agriculture is concern?
# - AM WAITING 4 THE INPUTS,
#
# --- Cluster 143 (size=1280) ---
# - How Can We minimise harvest losUPes from small scale farmers,
# - Is It Posible Afarmer to get agricultural doners
# - High Yield.
# - ,do too light affect yields
# - what should I do to get more yield?.
#
# --- Cluster 125 (size=1248) ---
# - What is afarm?
# - HOW WILL U HELP AFARM &WHEN?
# - how iz badizle uzeful 2 afarmer?
# - What should first have before i start afarm
# - What should i first have before i start afarm
#
# --- Cluster 196 (size=1220) ---
# - Where is wefarm found
# - Where is the headquaters of wefarm.
# - ,where is the headquaters of wefarm.
# - where are the headquaters of wefarm? am Dankan in kirima-kanungu
# - wefarmers is around where ?
#
# --- Cluster 101 (size=1176) ---
# - what is pomoculture
# - ,can horticulture contribute much on yields
# - What Is Hoti Culture?
# - what is horticulture?
# - what is mono-culture?
#
# --- Cluster 82 (size=1173) ---
# - WHAT IS DEFORESTATION
# - WAT IS DEFORESTATION
# - how do we conserve forests 4 better harvest?
# - types of forests
# - agro-forest
#
# --- Cluster 84 (size=1119) ---
# - -when grafting,the scion should be soft or woody?
# - What is grafting?
# - what is the importance of grafting?
# - n,wat iz grafting
# - What Is Grafting?
#
# --- Cluster 86 (size=1110) ---
# - What Is use of farm records and farmers can keep records of what?.
# - What are farm records?
# - What are importance of farm record?
# - what is the importance of farm records
# - what are the importance of taking farm records

# %%
# Integrates new noise cluster labels back into the main dataframe
unlabeled_df.loc[unlabeled_df["cluster"] == -1, "cluster"] = noise_labels_shifted

# %%
unlabeled_summary = summarize_clusters(unlabeled_df, 
                        text_col='Q_basic_clean', 
                        cluster_col='cluster', 
                        top_n_words=5, 
                        meta_col='meta_label', 
                        sample_questions=5, 
                        random_samples=True, 
                        preview=True
                        )
# Out:
# === Cluster -1 (size=157906) ===
# Keywords: use, wefarm, does, best, wat
# Meta: -1.0
# Sample questions:
#   - can i get an electrician post in your organisation?
#   - ,Are they capable to survive or
#   - Where can i get mint seeds pliz members help
#   - State the function of acotyledon.
#   - SOO FOR WHAT
#
# === Cluster 0 (size=3449) ===
# Keywords: mulching, mulch, importance, mulches, garden
# Meta: 4.0
# Sample questions:
#   - Why Do People Mulch Their Garden?
#   - Good Simon, Which Materials Do you use for mulching inorder keep the moist in the garden?
#   - what is mulching?
#   - am ask a qn to d'stance of mulching from bananaplant to other afarmers for more lnf?
#   - What Is Mulching ?
#
# === Cluster 1 (size=4401) ===
# Keywords: ticks, tick, control, best, farm
# Meta: 2.0
# Sample questions:
#   - Please Told Me Medicine Of Poison Of Tick
#   - what are the harmful effects of the tick
#   - Which is the best caracide for killing ticks?
#   - Which are the 2 example of two host tick
#   - mention three types of tick found in agri
#
# === Cluster 2 (size=1936) ===
# Keywords: silage, make, making, prepare, hay
# Meta: 3.0
# Sample questions:
#   - can someone please tell me how to prepare a silage
#   - how can silage be prepared
#   - How many days does silage take to be ready?
#   - How can you prepare silage?
#   - How can be silage prepared?
#
# === Cluster 3 (size=6217) ===
# Keywords: honey, beehive, harvest, harvesting, hive
# Meta: 3.0
# Sample questions:
#   - procedure for harv sting honey
#   - ,Can i harvest honey this season
#   - Why smoke used in honey haversting
#   - how much do a beehive cost
#   - Thx Julius, If i want modern hive, where can i find it in Mbara..
#
# === Cluster 4 (size=3239) ===
# Keywords: grazing, zero, pasture, paddocking, pastures
# Meta: 3.0
# Sample questions:
#   - What are differences btw rotational $ zero grazing ?
#   - i would like start a zerograzing using a one point is it enough for me to use it
#   - E iwant to know the best type of grazing (okurisa)
#   - how to farm grazing
#   - i meen zero grazing is it expentive
#
# === Cluster 5 (size=11107) ===
# Keywords: milk, production, milking, increase, acow
# Meta: 3.0
# Sample questions:
#   - WHAT TYPE SOLT CAN I USE TO INCREASE MILK PRODUCTION
#   - WHO. CAN BUY MY. MILK
#   - WHAT CAUSES MILK FEVER
#   - What is homogenized milk
#   - What is the cost of milk
#
# === Cluster 6 (size=2123) ===
# Keywords: mastitis, causes, control, cause, treat
# Meta: 3.0
# Sample questions:
#   - please alex,i asked that what is pest resergence but not mastitis
#   - The major couses of mastitis
#   - How To Control Mastitis
#   - Name two types of mastitis
#   - What Causes Mastitis?
#
# === Cluster 7 (size=2716) ===
# Keywords: rats, moles, rat, kill, control
# Meta: 2.0
# Sample questions:
#   - Whch types of chemicals do i use 2 kll moles?
#   - In my farm there are alot of mouses/fuko.How can i prevent$which way?
#   - n How can control mole rats in my gdn.?
#   - Mousebird Are Controled By
#   - Wat Can I Use 2kill Rats From my house?
#
# === Cluster 8 (size=4472) ===
# Keywords: ph, soil, lime, acidity, acidic
# Meta: 1.0
# Sample questions:
#   - what are the causes f soil ph
#   - What is the meaning of da word acidity regulator?
#   - how does a farmer test for soil ph?
#   - ,incase I want 2 test my farm soil ph,2 now type of fertiliser 2 used,where will i visit,i'm in kericho county
#   - soil has acid,what should i do to expect good harvest?
#
# === Cluster 9 (size=6176) ===
# Keywords: army, worm, worms, control, armyworm
# Meta: 2.0
# Sample questions:
#   - on spraying wit pestcide dat control cutworms wea do we spray particularly
#   - what are the characteristics of fall army worms?
#   - Describe the life cycle of Boophilus decoloratus
#   - S Which is the best method to control Fall Armyworm?
#   - which ways of controling cut worm
#
# === Cluster 10 (size=3045) ===
# Keywords: castration, dehorning, method, methods, castrate
# Meta: 3.0
# Sample questions:
#   - I want to know the of castration and how it is done
#   - -dehorning can be done using which methods?
#   - What is the importance castration as it is used afiel
#   - what are methods off castration
#   - What is de§horning.
#
# === Cluster 11 (size=1567) ===
# Keywords: fishing, pond, fingerlings, fishpond, catfish
# Meta: 3.0
# Sample questions:
#   - CAN FISHFARME REAR SILVERFISH?
#   - Where can i sell mudfish fingerlings?
#   - Give factors to consider when selecting asite for? afish pond
#   - How can i aquie fingerlings from busia county?
#   - How Can The Fingerlingx Be Produced
#
# === Cluster 12 (size=4731) ===
# Keywords: green, paper, house, greenhouse, greenpaper
# Meta: 4.0
# Sample questions:
#   - Evans asks,how can i be connected to greenhouse suppliers of flexible terms and quality materials?
#   - I have greenpaper but i need market.
#   - ,how is greenhouse maintained
#   - Which type of green paper is best for growing,
#   - MENTION IMPORTANCE OF GREEN HOUSE.
#
# === Cluster 13 (size=1561) ===
# Keywords: termites, ants, kill, control, use
# Meta: 2.0
# Sample questions:
#   - IF vaniilla is having black ants in its flowers ,is it bad?if yes give me a solution
#   - What kill termites?
#   - What Can I use To Control Ants In My Farm?
#   - what is the best pesticide for anthills
#   - HOW DO I CONTROL TERMITE IN MY FARM?
#
# === Cluster 14 (size=15273) ===
# Keywords: eggs, egg, incubator, lay, incubation
# Meta: 3.0
# Sample questions:
#   - After Planting Eggplanting What Can I Do
#   - please even before manual let me ask about breeds first that can fit for meat and eggs
#   - What is the price of a tray of eggs?
#   - how do you preserve eggs after hatching so that they don't get rotten
#   - Do Consumers prefer rich yellow yolk eggs only?
#
# === Cluster 15 (size=2862) ===
# Keywords: mixed, farming, cropping, croprotation, croping
# Meta: 4.0
# Sample questions:
#   - what is the importances of mixed farming?
#   - What z the meaning of the word mixed croping.
#   - what is mixing farming
#   - n Wat Is Mono Croping?
#   - Wat kid of mixed farming should i start,
#
# === Cluster 16 (size=1722) ===
# Keywords: prunning, pruning, thinning, thining, pricking
# Meta: 4.0
# Sample questions:
#   - I Want To Know The Meaning Of PrunningQ
#   - wt is prunning?
#   - does thinning differ 4rm prunning NR-!
#   - What if i fail to prune but i use indofil,mancozeb 45w is it also ok
#   - What is prunning
#
# === Cluster 17 (size=1835) ===
# Keywords: loan, loans, farmers, farm, wefarm
# Meta: 6.0
# Sample questions:
#   - is there any loan to support my farming?
#   - i need a loan how can i get it and where can i go for the farmer loan
#   - can wefarm give seedlings on loan?
#   - , like which farm should i borrow money from?.
#   - Do wefarm give loans to farmers iam in kamuli
#
# === Cluster 18 (size=3406) ===
# Keywords: loan, loans, wefarm, borrow, offer
# Meta: 6.0
# Sample questions:
#   - do you offer loans
#   - how can l get anyform of loan frm wefarm
#   - Kindly anyone too help me 300 will refund on thursday with an iterest of 150
#   - Do you give loan to the members
#   - HOW CAN I GET LOAN IN WEFARM?
#
# === Cluster 19 (size=1744) ===
# Keywords: sampling, soil, testing, test, sample
# Meta: 1.0
# Sample questions:
#   - what is the important of soil testing
#   - Which part of mbarara can i get a soil testing lab bse am in isingiro
#   - where in Uganda can I do my lab soil tests from
#   - Is it adviceable for sitting a green house to any soils without testing in a laboratory?
#   - how am I going to testify the soil please?
#
# === Cluster 20 (size=1699) ===
# Keywords: fertility, fertile, land, infertile, infertility
# Meta: 1.0
# Sample questions:
#   - .how can you help(female) that does no get pregnant/concieve..
#   - destingush between fertility and inferlity.
#   - HOW TO MAKE A LAND GAINS ITS FERTILY.
#   - wat can i do 2 make land fertile
#   - how can i improve fertility in my farm since it doesnt produce quality produce
#
# === Cluster 21 (size=4998) ===
# Keywords: erosion, soil, control, hilly, prevent
# Meta: 1.0
# Sample questions:
#   - resp'd afibrous main soft root,awell maintained topsoil with erosion free condusive envm't/area.
#   - causes of soil erosion? to 6333
#   - what about the type of soil; the slope of land;soil depth ;overstocking and vegetation cover can be factors that influence soil erosion?
#   - Am GODWIN from sheema.my qn is what causes soil erosion?
#   - Am asking qn what is soil erosion
#
# === Cluster 22 (size=4116) ===
# Keywords: soil, fertility, improve, fertile, ways
# Meta: 1.0
# Sample questions:
#   - MY SOIL IS NOT OKAY WHAT CAN I DO
#   - WHAT ARE THE FACTORS AFFECTING SOIL FERTILITY?
#   - Reproduction is the process by which Living things produce their young ones and multiple in numbers,How can one improve on soil fertility ,Ask by Okumu Emma,
#   - WHAT CAUSE SOIL TO LOOSE FERTILITY
#   - MBUUZA: HOW TO IMPROVE SOIL FERTILITY WITHOUT USING ARTIFICIAL FERTILIZERS.
#
# === Cluster 23 (size=4655) ===
# Keywords: soil, type, clay, best, good
# Meta: 1.0
# Sample questions:
#   - Famers What Is soil Taxture ,
#   - what is soil solarization
#   - whats is loam soil
#   - what type ov soil iz suitable 4 growing cabagge?
#   - the best soil 4 planting kitungu saumu is wit wat amount of rainfall
#
# === Cluster 24 (size=2779) ===
# Keywords: heat, acow, warm, signs, army
# Meta: 3.0
# Sample questions:
#   - which is the most reliable way of dealing with army warms?
#   - What is the best period melting apig
#   - What Are The Signs Of Apig On Heat.?
#   - I Have Acow That Ever On Heat How Can I Stop It From That Charecter
#   - acow takes how long on heat
#
# === Cluster 25 (size=1524) ===
# Keywords: house, timber, materials, build, measure
# Meta: 7.0
# Sample questions:
#   - how about materials like food and which kind of housing is favourable
#   - how much per feet
#   - What is the tool necessary 4 building
#   - Highlight Some Of The Causes Of Dampness In Timber
#   - to joseline,is it in metres or feets?
#
# === Cluster 26 (size=5245) ===
# Keywords: breed, breeding, breeds, cross, inbreeding
# Meta: 3.0
# Sample questions:
#   - I lack exotic what should i do?
#   - where can I find pedigree saanen and at how much or can I get a farmer who can exchange to avoid inbreeding
#   - WILL IT BE POSSIBLE CROSS VACANDO TO ANOTHER
#   - Faith asks: characteristics of exotic breeds?
#   - which breed is suitable in Bomet county
#
# === Cluster 27 (size=2899) ===
# Keywords: donkey, elephant, horse, donkeys, young
# Meta: 3.0
# Sample questions:
#   - The Genus Name For Leopard Is? Am Kevin.
#   - how Can I Rare Hyenas?
#   - What are the dimensions of a cart that fits two donkeys to pull
#   - How Do I Deworm A Donkey ?
#   - What is that scientifical name four an elephant?
#
# === Cluster 28 (size=3047) ===
# Keywords: tractor, plough, ploughing, dig, engine
# Meta: 7.0
# Sample questions:
#   - Can l use tractor at the time of harvesting.
#   - for how long the land should be plan after digging
#   - what is the use of the farrow wheel?
#   - WE HAVE HOW MANY TRACTORS ENGINE?
#   - Wat iz ox-ploughing
#
# === Cluster 29 (size=4518) ===
# Keywords: vaccine, newcastle, fowl, pox, vaccination
# Meta: 3.0
# Sample questions:
#   - What the medicine of birdflu
#   - what prevents foul pox
#   - Pauline How Can I Vaccinate Them Using Which Madicine
#   - what is the signs of fowlpox virus diseases and how can i prevent by using which medicene?
#   - Which vaccine can you use to prevent seasonal out break of diseases?
#
# === Cluster 30 (size=2808) ===
# Keywords: water, drainage, farm, use, pollution
# Meta: 8.0
# Sample questions:
#   - , Gve Function Of Water? Nice Lunch As U Answer
#   - how many times did acow takes water a day?
#   - what is soil drainage
#   - what are problems of drainage
#   - Name three sources of water.
#
# === Cluster 31 (size=3834) ===
# Keywords: irrigation, pump, water, solar, drip
# Meta: 7.0
# Sample questions:
#   - can a solar water pump pump water a cross the hill
#   - WHAT IS THE USE OF A WATER PUMP
#   - where will i get pipes for drip irrigation.
#   - How much is an irrigating pump?
#   - I want 2 buy sprinklers but where can find them and at what price?
#
# === Cluster 32 (size=9156) ===
# Keywords: food, feed, feeds, eat, meat
# Meta: 3.0
# Sample questions:
#   - how can i start pork keeping.am from matinyani in kitui county
#   - which food can i use to improve?
#   - reply q how can i start fatming
#   - why a xheep refuxed to eat,
#   - What are the problems associated with beef production?
#
# === Cluster 33 (size=1618) ===
# Keywords: salt, milk, mineral, best, type
# Meta: 1.0
# Sample questions:
#   - i have been using utramix maziwa. which salt is preffered.
#   - what is the recomended mineral .
#   - uestion of de day says that: Name 4 types of minerals? Nice weekend
#   - Why Is It That Farm Produce In Areas Sorrunding Lk.Naivasha Are Not Salty Yet The Water Is Salty? Any Idea
#   - have tried 3 types of joto salt and its not working
#
# === Cluster 34 (size=2678) ===
# Keywords: foot, mouth, disease, teeth, causes
# Meta: 2.0
# Sample questions:
#   - HOW DO WE TREAT FOOT AND MOUTH DISEASE?
#   - , what what are the curetive drugs of foot and mouth
#   - how do I fight foot and mouth disease?
#   - what is the best medicine to treat foot and mouth
#   - How do you control foot and mouth dis
#
# === Cluster 35 (size=1522) ===
# Keywords: wilt, bacteria, wilting, bacterial, control
# Meta: 2.0
# Sample questions:
#   - how can i treat backteria wilt in the soil?
#   - What Is Wilting? Here Is Ajob Call 0774246722
#   - How do bacterial reproduce?
#   - What cause poteto wilting?
#   - What are solution to bacterial wilt?
#
# === Cluster 36 (size=4860) ===
# Keywords: sex, vagina, penis, semen, wat
# Meta: 10.0
# Sample questions:
#   - bacuse it sweet
#   - How to be fucked
#   - Things To Do To Make My Penis Erect At Night During Sex
#   - WHERE CAN I GET BEST SEMEN FOR BUNGOMA COUNTY
#   - Is there also women
#
# === Cluster 37 (size=1933) ===
# Keywords: wefarm, champion, win, winner, won
# Meta: 9.0
# Sample questions:
#   - How can I win 10000 at this wefarm?
#   - Who Is the winner of wefarm tugabane?
#   - How can i knew,that im a champion wefarm member?
#   - How many days remaining for wefarm champions promotion to end?
#   - What has happened with wefarm server machine, who is the winner?
#
# === Cluster 38 (size=3749) ===
# Keywords: win, winner, winners, champion, won
# Meta: 10.0
# Sample questions:
#   - what do you consider for someone to be a champion
#   - what prize would you gve me
#   - WHO WIN yesterday
#   - UESTION REPLY WIN SH 10000
#   - please i want my prize
#
# === Cluster 39 (size=2770) ===
# Keywords: dressing, fertilizer, topdressing, dress, best
# Meta: 1.0
# Sample questions:
#   - Which one is the best manure for top dressing.
#   - ,TOP DRESSING FERTILIZER
#   - Does Pinable Top Tressed
#   - manures used for top dressing
#   - What is d correct proportion of mixing D.A.P and urea fertilizers for top dressing?
#
# === Cluster 40 (size=12474) ===
# Keywords: fertilizer, fertilizers, use, best, dap
# Meta: 1.0
# Sample questions:
#   - What is artificial fertilizer?(inorganic fertilizer)
#   - uestion: can i use baraka fertilizer?
#   - mixing of weed ,water and ash is it good for making ferterizers
#   - best fertilizer is?
#   - Whats The Best Fertiliser For Planting
#
# === Cluster 41 (size=6711) ===
# Keywords: manure, compost, organic, use, make
# Meta: 1.0
# Sample questions:
#   - which type of manure is best in the garden?
#   - WHICH TYPES OF MANURE DO YOU APPLY
#   - Which Manure Do I Use For Top Dresing?
#   - gve four types of manurez
#   - what are the advantages of compost manure over atifisial manure
#
# === Cluster 42 (size=1867) ===
# Keywords: sprayer, litres, knapsack, litre, water
# Meta: 7.0
# Sample questions:
#   - Hw many mls of weedmaster in 20ltrs of spray pump?
#   - How many litres can an esheire produce a day?
#   - How Much Is An Eight Litter Pressure Sprayer?
#   - ;how is the selling per litre?
#   - how much is weed mastor in mbarara one little.
#
# === Cluster 43 (size=1842) ===
# Keywords: chemical, chemicals, use, best, used
# Meta: 1.0
# Sample questions:
#   - Then which chemical can i use
#   - can wefarm assit me with 1000/= to buy chemicals?
#   - which type of chemicals
#   - the name of the chemicals
#   - Which chemical is strong in panadol and kwinin?
#
# === Cluster 44 (size=3845) ===
# Keywords: spray, spraying, use, chemical, chemicals
# Meta: 1.0
# Sample questions:
#   - Which chemical should I use to spraying
#   - , how long can acow be sprayed
#   - the best time to spray acow
#   - Sawa ,then which chemical to used in spraying
#   - i had of the new roundup what is its name and how does it work
#
# === Cluster 45 (size=1757) ===
# Keywords: control, prevent, hw, controlled, bbw
# Meta: 2.0
# Sample questions:
#   - HOW I CAN CONTROL INTENAL PERASITE
#   - And how can i control it?
#   - Hw cn i control
#   - how to control nimonia?
#   - #Tsetse can be controlled by what
#
# === Cluster 46 (size=7357) ===
# Keywords: medicine, disease, diseases, use, treat
# Meta: 2.0
# Sample questions:
#   - ,which disease is caused by avian coronavirus
#   - how can i do to get the medicine
#   - Which disease are the suffering from
#   - which drug can l use to treat metritis
#   - ,What is notiferable disease?
#
# === Cluster 47 (size=1611) ===
# Keywords: skin, eyes, eye, disease, acow
# Meta: 2.0
# Sample questions:
#   - what Can J Do When Acow Has Wounds On The Titts?Thanks
#   - CAN ACOW WHICH IS TOTALLY BLIND BE TREATED ?
#   - ,How Can skin disease be treated?
#   - What brig's wounds on hans
#   - regional lymph nodes are swollen and edema develops in udder and legs
#
# === Cluster 48 (size=9467) ===
# Keywords: pests, pest, control, use, pesticide
# Meta: 2.0
# Sample questions:
#   - Which i pestside is good for sprayng personfruits during growth
#   - ,how to reduce pest and diseases in farms?
#   - Ways of controlling pest in afarm
#   - EXAMPLE OF PESTICIDES
#   - How many types ofcrop pests
#
# === Cluster 49 (size=2469) ===
# Keywords: herbicide, herbicides, weeds, best, use
# Meta: 1.0
# Sample questions:
#   - iam asking again which pesticides are required mostly to prevent weeds?
#   - where can i get herbacides that i can use, am in mbarara?
#   - Which non selective herbicide is the best for curbing weeds?give you reason to support you answer.
#   - Kapkiyai jnr.nandi county taunet center... Which is correct herbicides to be used which has no sight effects to human
#   - Which Herbicide Can i use to spray the bush for it to become very dry for digging?
#
# === Cluster 50 (size=7273) ===
# Keywords: weeds, weed, weeding, control, farm
# Meta: 1.0
# Sample questions:
#   - whats wrong with weed monster
#   - what are reasons that have made weeds hard to control?
#   - Hw can u overcome this weed ereusine ratiphoria
#   - how to prevent the weed from the farm
#   - How can we control weeds in the garden to day
#
# === Cluster 51 (size=6884) ===
# Keywords: rain, season, weather, rainfall, raining
# Meta: 8.0
# Sample questions:
#   - When will the long Rains for the planting season start in Baringo county?And for how long?
#   - is it raining there in this month
#   - its dry in kilifi xo far.no rains observed when are we expecting rains
#   - When will the rain start seriously this season?
#   - ;Hey Wefarm! u all know that in some places there is no enough rain,now which is the best method of irragation should i use 2 make sure is enough 4 my farming activities and other chores without wasting it?
#
# === Cluster 52 (size=4088) ===
# Keywords: fruits, fruit, flowers, flower, flowering
# Meta: 4.0
# Sample questions:
#   - What kind of can i apply to passion during flowering
#   - How can i make my home fruits juice?
#   - How long do crossed ovacado take to get fruits?
#   - fasion fruits)How leght+wiht is?
#   - Fruits of ovado become black and drop down,what type of diseases
#
# === Cluster 53 (size=2778) ===
# Keywords: sukuma, leaves, yellow, leaf, yellowish
# Meta: 4.0
# Sample questions:
#   - ,qn10,to remove diseased leaves or unwanted leaves to improve on high yields
#   - , my beens leaves become yellow.
#   - Why Pinnapple'leaves Becomes Yellow In My Garden. Am Fred From Lutooma-mubende.
#   - what causes the yellowing of riceleaves?
#   - \nMy pilipili hoho has brown dotted spot on leaves what might be the problem
#
# === Cluster 54 (size=3305) ===
# Keywords: bed, nursery, transplanting, nursary, anursery
# Meta: 4.0
# Sample questions:
#   - What is the best method of prepairing beds
#   - how is a nursery bed prepared?ni mercy from Lusoi ,Nyeri sub country.
#   - outline the factors cosinderd when sitting a nursery bed
#   - how can a person raise a nursery
#   - Which kind of faterlizer do i have to use when preparing nursery?
#
# === Cluster 55 (size=8404) ===
# Keywords: long, does, period, birth, mature
# Meta: 3.0
# Sample questions:
#   - Adog Has Alifespan Of How Many Years?
#   - How long does long 5 take to mature?
#   - S: is there any scientific prove that, a placenta has negative effect in acow?
#   - what is the cause of remating with no pregnancy?
#   - How long does apig take to start giving birth?
#
# === Cluster 56 (size=1569) ===
# Keywords: deworming, deworm, best, medicine, dewormer
# Meta: 3.0
# Sample questions:
#   - What could have made mycow's far change yet i dewarmed last week.
#   - Deworming Should Be Done After How Many Months
#   - WHAT IS DEWORMING?
#   - Which method is good for deworming
#   - Which is the best dewormer,solid or liquid?
#
# === Cluster 57 (size=10479) ===
# Keywords: seeds, seed, germination, seedlings, best
# Meta: 4.0
# Sample questions:
#   - what is a seed.? 6333
#   - How do you choose seeds?
#   - what about the seeds of managu
#   - is there nakati seeds in nakasero market?
#   - what is seed domarcy?
#
# === Cluster 58 (size=2350) ===
# Keywords: bed, seedbed, seed, seedlings, nursery
# Meta: 4.0
# Sample questions:
#   - At What Stage Can A Farmer Transplant His Seedlings?
#   - ,after which period do seedlings ready for transplanting
#   - HOW OLD ARE THEY?SEEDLINGS,READY TO HARVEST,MIDLO,OR ONE MONTH IN GARDEN?
#   - How many days does a seedling stay in a seedbed?
#   - What is the procedure of putting in seedbed
#
# === Cluster 59 (size=1833) ===
# Keywords: harvest, long, harvesting, harvested, does
# Meta: 4.0
# Sample questions:
#   - R for how long does marenge can be ready to harvest
#   - who is a harvestor
#   - Oaths takes how long to mature and ready to be harvested from the day of planting?
#   - first harvest should be after what period after planting?
#   - How long does vanila take to harvest
#
# === Cluster 60 (size=4679) ===
# Keywords: planting, grow, season, best, planted
# Meta: 4.0
# Sample questions:
#   - After bedding and planting what can I do next to enable them grow well.
#   - HOW CAN I GROW TEAR GAS
#   - Why do my not grow
#   - What kind of it will I use before planting
#   - Can be used after planting?
#
# === Cluster 61 (size=5052) ===
# Keywords: uganda, agriculture, wefarm, minister, farmers
# Meta: 9.0
# Sample questions:
#   - who is the wefam c/p in uganda
#   - What are the systems recomended in Uganda.
#   - Why js artjfjcjal jnsermjnation not common jn uganda
#   - Give three reasons why north east part of Uganda is a semi-desert area and its effects agriculture in the country ?
#   - I want to no where they land hw to drive aroplain in uganda where?
#
# === Cluster 62 (size=3398) ===
# Keywords: kenya, nairobi, agriculture, wefarm, best
# Meta: 9.0
# Sample questions:
#   - Where is wefarm offices in Kenya?
#   - which universities in kenya offers courses in agriculture?
#   - what is the important of agriculture in kenya
#   - :what are the importance of agriculture to the economy of kenya
#   - what are the factors that AGIRCULTURE have contributed to economic of the kenya.?
#
# === Cluster 63 (size=1536) ===
# Keywords: located, place, stay, exactly, location
# Meta: 10.0
# Sample questions:
#   - Where a you situated
#   - i meant outside the country
#   - E Where are you now?
#   - WHERE CAN I FIND YOU
#   - where do u leave?
#
# === Cluster 64 (size=4410) ===
# Keywords: join, group, job, want, member
# Meta: 10.0
# Sample questions:
#   - how can l become a member
#   - n what are your names all members
#   - where can i get someone want job here?
#   - ue. What Is The Essantial Qualification For One To Benefit From These Services ? .
#   - ,invited a friend 0728002989
#
# === Cluster 65 (size=2374) ===
# Keywords: agroforestry, agro, agric, agri, agribusiness
# Meta: 1.0
# Sample questions:
#   - what is agrofaming?
#   - -what is agroforest
#   - What are the appropriat size of agroforest?
#   - What are agro industry?
#   - What Is Agri
#
# === Cluster 66 (size=1534) ===
# Keywords: use, type, best, types, used
# Meta: -1.0
# Sample questions:
#   - Which type is it?
#   - HOW TO USE IT?
#   - hw do i use it
#   - What is animla?
#   - What is the meaning of acrisis
#
# === Cluster 67 (size=3329) ===
# Keywords: wefarm, farmers, farmer, champion, farm
# Meta: 9.0
# Sample questions:
#   - Do Wefarm system allowed farmers to chats with others?
#   - is the champion farmer still in progress
#   - When will wefarm champion farmer chalenge end.
#   - WEFARM IS A GROUP THAT UNITES FARMERS IN KENYA.IT IS FARMERS ASK QUESTION AND GET ANSWERED.FARMERS GET INFORMED ABOUT NEW SEED AND THE BEST SEED,WHICH FERTILIZER TO APPLY AT EVEVY STAGE OF A PLANT.
#   - HOW do a farmer benefit from a wifarm?
#
# === Cluster 68 (size=17679) ===
# Keywords: farm, farming, farmer, farmers, start
# Meta: 10.0
# Sample questions:
#   - what about other farmers?
#   - How can if i need 2 talk 2 my fell farmers on 4n.
#   - l want to be a water farmer
#   - , I WANT TO START BIGS FARMING, SOMEONE TO GIVE ME THE PROCEDURE HOW TO START,MANAGE,TYPE OF FEEDS GOOD FOR THEM AND MARKETING
#   - where are you farmers?
#
# === Cluster 69 (size=2565) ===
# Keywords: agriculture, agricultural, term, factors, importance
# Meta: 1.0
# Sample questions:
#   - _ Millers not include agriculture
#   - Whats the importants of Agricultural
#   - 6333 wht is agriculture?
#   - R what is agriculture?
#   - help me 2 no ze meaning of agriculture
#
# === Cluster 70 (size=6530) ===
# Keywords: number, contact, phone, contacts, want
# Meta: 10.0
# Sample questions:
#   - ;what if i say i love caroline
#   - I Wld Lyk Pple 4rm Kakamega To Take My No. I Want To Suply Them With Chicks0708427753
#   - S I Lv U 0746362699
#   - How can i get farida number?
#   - plz what is hos Mary
#
# === Cluster 71 (size=3100) ===
# Keywords: capital, business, start, project, profit
# Meta: 6.0
# Sample questions:
#   - What could be the possible source of capital?
#   - l have my capital ov 2million what next
#   - ASSIST ME WITH 500
#   - How to use 1000= as a capital
#   - IHAVE CAPITAL WHERE TO GET THE BEST
#
# === Cluster 72 (size=1513) ===
# Keywords: money, pay, help, need, want
# Meta: 6.0
# Sample questions:
#   - Eric asks: How Can I Get Money?Am Mathias From Mayuge. Reply Q269 followed by your response. optout stop 6333
#   - How much after distribution? Meaning down payment.
#   - E When will i receive the money 0774686496.
#   - GIVE ME SOME MONEY
#   - When will we start earning
#
# === Cluster 73 (size=10253) ===
# Keywords: answer, question, questions, ask, help
# Meta: 10.0
# Sample questions:
#   - repeat your Quetion
#   - Can i recieve some questions?
#   - So what iz the answer?
#   - When will my questions answered?
#   - How Do I Answer A Question
#
# === Cluster 74 (size=14195) ===
# Keywords: price, market, cost, kg, sell
# Meta: 5.0
# Sample questions:
#   - Edwin,how Much Does It Cost?
#   - How Much Is Ashirin.
#   - How much is akilogram
#   - How much money can use to buy one kg of cowbean
#   - Where Can I Get 5000 per kg
#
# === Cluster 75 (size=2471) ===
# Keywords: bags, acre, bag, fertilizer, sack
# Meta: 1.0
# Sample questions:
#   - How many bags of fertilizer can i use in 1 acre?
#   - 259 how much can i get a bag of kalimbwe? Am located in kakola walusubi mukono
#   - wat is de price of sack of ripen ben?
#   - how many KGS of CN fertiliser goes in one accre piece of land
#   - what quantity of fertilizers are supposed to be applied in 1/2 acre of land pliz ans?
#
# === Cluster 76 (size=6287) ===
# Keywords: land, acre, preparation, prepare, acres
# Meta: 7.0
# Sample questions:
#   - what is the price of land in timboroa?
#   - The fast stage of land preparation is.
#   - how much is an acre in your district have a blessed sunday morning dia farmer
#   - I want get land for farming wat can i do?
#   - what could be the length of an acre of land with a width of 40 foot paces?
#
# === Cluster 77 (size=10469) ===
# Keywords: wefarm, join, benefit, members, want
# Meta: 9.0
# Sample questions:
#   - How Can i benefit 4rm wefarm group or company ? reply my qn 1 followed by your response,
#   - How should i join wefarm
#   - How can i benefit in wefarm?
#   - why does the wefarm company supply mask and sanitizers during this pandemic and food maybe for the most vulnarable members
#   - any one with wefarm contacts send them 2me now gd nyt
#
# === Cluster 78 (size=1973) ===
# Keywords: day, good, night, morning, happy
# Meta: 10.0
# Sample questions:
#   - E gd evening ma friends
#   - good afer noon
#   - ,good evening to my best friends. happy sunday.
#   - Hw Do U Predict X-mas?
#   - E abalimi nabalunzi HAPPY CRISMAS AND NEW YEAR.
#
# === Cluster 79 (size=6616) ===
# Keywords: english, county, kiswahili, kericho, district
# Meta: 10.0
# Sample questions:
#   - Where are you in Busia Coletta?
#   - What about location BWEZI BWERA
#   - Adam tell me how to use OMUTINBAGANO
#   - What is the name of(ebitonganwa) in english?
#   - Iwant.2.Be.Acoordinator.Of.Kabarole.District
#
# === Cluster 80 (size=2908) ===
# Keywords: wefarm, offices, office, shop, located
# Meta: 9.0
# Sample questions:
#   - Philemon asks: Wakulima Suppliers is in Kericho County an i in Nandi pliz get me the nearest Wefarm Agent Reply Q1426 followed by your response.
#   - where in mbarara is the shop of wefarm?
#   - WHERE CAN I GET WEFARM SERVICES IN KABALE
#   - Ohh i thank this programme thnx wefarm bambi ohh where can we find the main offices
#   - Where are wefarm offices in kaliro district
#
# === Cluster 81 (size=470) ===
# Keywords: apiculture, culture, iz, wat, asks
# Meta: 3.0
# Sample questions:
#   - what is apiculture.
#   - ,what is apiculture.
#   - Which Place Is Convinience For Practicing Apiculture
#   - whatc the difference btn hoticulture and apiculture?
#   - n:amanya asks,what is apitherapy
#
# === Cluster 82 (size=1173) ===
# Keywords: forestry, agro, forest, deforestation, aforestation
# Meta: 1.0
# Sample questions:
#   - which instrument used for deforestation in time?
#   - AFARMER ASKS WHAT IS AGRO FORESTRY
#   - What is Agro... Forestry ?
#   - what is agro forestry
#   - Felix asks: what are major causes of deforestation. Reply Q117 followed by your response. optout stop 6333
#
# === Cluster 83 (size=550) ===
# Keywords: pollination, cross, self, types, asks
# Meta: 4.0
# Sample questions:
#   - how many types of pollination do we have.
#   - pollad and brains
#   - What z cross pollination?
#   - what is the importance of pollinators
#   - What is sex pollination
#
# === Cluster 84 (size=1119) ===
# Keywords: grafting, staking, budding, importance, grafted
# Meta: 4.0
# Sample questions:
#   - DON ASKS:What is grafting?
#   - What Is Grafting
#   - What is grafting?.
#   - what's staking?
#   - ..which is the best grafting method
#
# === Cluster 85 (size=712) ===
# Keywords: locust, locusts, control, prevent, farm
# Meta: 2.0
# Sample questions:
#   - Locust which colour and where they lay eggs?.
#   - Which medicine l wii use to control locuse
#   - How do I spray locust in plantation
#   - what can afarmer do to control locusts?
#   - n.is it true dat locusts apened 2 b in uganda
#
# === Cluster 86 (size=1110) ===
# Keywords: records, farm, record, keeping, importance
# Meta: 7.0
# Sample questions:
#   - What are the uses of farm records in the farm?
#   - State The Classification Of Farm Records
#   - ,Why should afarmer keep farm records?
#   - What are production record?
#   - help to name some of farm record
#
# === Cluster 87 (size=740) ===
# Keywords: intercropping, intercroping, ley, advantages, monocropping
# Meta: 4.0
# Sample questions:
#   - how is monocropping advantageous than intercropping
#   - does intercropping affects production
#   - What is interdependance?
#   - what is intercropping
#   - -What's intercroping
#
# === Cluster 88 (size=496) ===
# Keywords: cultivation, shifting, shift, advantages, disadvantages
# Meta: 4.0
# Sample questions:
#   - What z shifting cultivation?? Evng??
#   - advantage of shfting cultivation
#   - Why Are In Some Areas Shift Cultivation Is Practiced
#   - ,what is shifting cultivation?
#   - E advantages of shifting cultivation
#
# === Cluster 89 (size=790) ===
# Keywords: hay, make, making, bale, quality
# Meta: 9.0
# Sample questions:
#   - wat is hay?
#   - which one is which now is it dairymeal or hay ?
#   - where can i get hay
#   - how do we determine the quality of hay
#   - Is There Any One Who Knows About Hay Farming.
#
# === Cluster 90 (size=1096) ===
# Keywords: insemination, artificial, advantages, natural, disadvantages
# Meta: 3.0
# Sample questions:
#   - why is it that artificial insemination is not commonly used in western region?
#   - outline more than three factors limiting the use of artificial insemination?
#   - what is artificial insemination
#   - How effective is artificial insemination in women? and how costly,affective is it?
#   - ,where can i get artiffitial insemination services.
#
# === Cluster 91 (size=684) ===
# Keywords: photosynthesis, fym, tropism, wat, photo
# Meta: 4.0
# Sample questions:
#   - WHAT IS Photosynesis?
#   - Whats photosynthesis?
#   - to give it energy and boost it to grow faster,inshot for photosythesis
#   - what is pica finex
#   - What is photo synthesis?
#
# === Cluster 92 (size=1364) ===
# Keywords: vanilla, long, does, grow, planting
# Meta: 4.0
# Sample questions:
#   - ,i want to know hw to raise vanilla from seedling up to harvesting
#   - Where Should I Get Vanilla
#   - whow can i know that my vanilla is mature
#   - What are uses of vanilla?
#   - Which the best soils for vanilla, Can it grow well in Bushenyi district ?
#
# === Cluster 93 (size=845) ===
# Keywords: tillage, minimum, tilage, primary, tilling
# Meta: 7.0
# Sample questions:
#   - State the farm tools and equipments used in secondary tillage
#   - What is minmum tillage?
#   - Give Reasons 4 Inverting Soil Slices During Primary Tillage
#   - S define minimum tilage
#   - What is minmum tillage.
#
# === Cluster 94 (size=454) ===
# Keywords: leaching, soil, causes, control, prevent
# Meta: 1.0
# Sample questions:
#   - how to reduce leaching of minerals
#   - How Can I Protect Manure From Leaching,
#   - ,what are advantages of soil leaching ? Reply now
#   - n what is soil leaching
#   - WHAT SHOULD I DO TO AVOID LEACHING IN THE FARM
#
# === Cluster 95 (size=438) ===
# Keywords: bloat, bloating, causes, meaning, control
# Meta: 3.0
# Sample questions:
#   - What are the stop bloat
#   - # What Is Bloating,?
#   - what are the causes of bloating?
#   - define the term bloat
#   - Define the term" bloat" en its causes
#
# === Cluster 96 (size=495) ===
# Keywords: anthrax, signs, causes, control, cause
# Meta: 3.0
# Sample questions:
#   - How is anthrax treated
#   - What is anthrax and how can it be controlled?
#   - Wat is anthrax?
#   - how to prevent anthrax
#   - what are sptoms of anthrax
#
# === Cluster 97 (size=868) ===
# Keywords: burning, bush, land, burn, clearing
# Meta: 8.0
# Sample questions:
#   - what is burning vegetation cover?
#   - Why Burning As A Methon Of Clearing Farm Is Discorage?
#   - What's bush burning (0757175307)
#   - S if you burnt a land before planting will the land be more fertile.
#   - What are bursh burning?
#
# === Cluster 98 (size=1010) ===
# Keywords: dormancy, seed, dispersal, breaking, causes
# Meta: 4.0
# Sample questions:
#   - What are seed dormancy and cause.
#   - What iz seed dormancy
#   - what is seed dormancy?
#   - Richard asks: WHAT IS SEED DORMANCY
#   - what causes seed dormancy?
#
# === Cluster 99 (size=888) ===
# Keywords: aphids, control, best, aphid, chemical
# Meta: 2.0
# Sample questions:
#   - How can we control aphids apart from spraying
#   - which Method is approximate when Controlling aphids on the fam
#   - how does aphids should be controlled in that intercropping please Munyekenye Stephen bungoma county
#   - what Can I Use To Control Fallworm And Aphids?
#   - What Method Should I Use To Comtrol Amphids?
#
# === Cluster 100 (size=839) ===
# Keywords: fence, fencing, wire, fences, farm
# Meta: 7.0
# Sample questions:
#   - important of fence
#   - (1a) what is afence (2b) advantages of fencing farm land.
#   - What are the general uses of fencing to afarmer
#   - Practices that makes wooden fence to last longer.
#   - is it good 2 use concrete wall fence in swampy areas Q
#
# === Cluster 101 (size=1176) ===
# Keywords: horticulture, culture, monoculture, hotculture, pomoculture
# Meta: 4.0
# Sample questions:
#   - What is Hotculture?
#   - What Is Hot Culture
#   - What Is Mono Culture?
#   - what is pomoculture?
#   - am joseph,shalom,what does equaculture means?and where is it located?
#
# === Cluster 102 (size=972) ===
# Keywords: fever, east, coast, cost, causes
# Meta: 3.0
# Sample questions:
#   - Tom Say Hw Cn U Treat Swin Fever In Pigz.
#   - am tied with east cost fever,what should i use?
#   - Wch is the best drugs 4 east cost fever?
#   - WATiz d best drug fo east coast fever
#   - i want the name of east coast fever vaccine
#
# === Cluster 103 (size=467) ===
# Keywords: gumboro, disease, signs, treat, causes
# Meta: 3.0
# Sample questions:
#   - what is the course of gumboro diseases
#   - what is gumbora
#   - What is GUMBORO,
#   - ,Signs and symptoms of gumboro and treatment
#   - what are the signs of cumboro?
#
# === Cluster 104 (size=742) ===
# Keywords: snake, snakes, mammals, frogs, frog
# Meta: -1.0
# Sample questions:
#   - -I HAVE A NEIGHBOUR WHO HAS A BUSHY PLACE, THERE IS A RISK OF SNAKES ! WHAT CAN I USE.
#   - Does a snake have a penis. End how can it work.
#   - What happens to the body temperature of a lizard when it hides under a cold_rock.
#   - why is abat called aflying mammal
#   - What is the frog eggs name?
#
# === Cluster 105 (size=516) ===
# Keywords: ai, services, advantages, meaning, using
# Meta: -1.0
# Sample questions:
#   - Ok but how much can AI cost?
#   - what are the disadvantages of AI?
#   - what is the best AI breed that i can use as a small scale farmer
#   - What Is The Meaning Of AI
#   - what is the meaning AI?
#
# === Cluster 106 (size=940) ===
# Keywords: biogas, gas, air, bio, make
# Meta: 1.0
# Sample questions:
#   - which way can we use to put biogas in a cylinder?
#   - WHAT IS MEANT BY BIOGAS
#   - What is a biogas digester?
#   - Wat Iz Air?
#   - SJe, nisaidieni na methods of constracting a bio gas?
#
# === Cluster 107 (size=421) ===
# Keywords: bananaplantation, bananawilt, bananaplant, control, manure
# Meta: 2.0
# Sample questions:
#   - What do we prevent bananapasts
#   - how can bananawilt be prevented
#   - Wat fertilizer can i use 2 make bananaplant 2 grow well and fast
#   - Am Saviour.Whatname is given to a pest that eats bananaleaves
#   - How many fouts should i leave from onebanana planttoanother bananaplant while iam thinning Reply Q57 thank you.
#
# === Cluster 108 (size=753) ===
# Keywords: cultivation, primary, secondary, importance, tertiary
# Meta: 4.0
# Sample questions:
#   - Wat Is Cultivation?
#   - What is second cultivition?
#   - Why do we cultivate?
#   - what is the advantage of secondary cultivation
#   - i want 2 knw factors that can reduce the no of secondary cultivations
#
# === Cluster 109 (size=713) ===
# Keywords: conservation, clean, sanitation, environment, environmental
# Meta: 8.0
# Sample questions:
#   - how to make famer clean
#   - ,What iz sanitation
#   - A Part From Cleanliness What Else?
#   - ,what is ecology?
#   - What is ecosystem?
#
# === Cluster 110 (size=5219) ===
# Keywords: soil, profile, texture, control, structure
# Meta: 1.0
# Sample questions:
#   - what are the causes of soil exhaustion?
#   - How Will You Identify The Type Of Soil, Is Good To This Kind Of The Seed?
#   - ways of controlling soil erosoin especially in hilly areas
#   - What Is Capillarity In Soil?
#   - How Do You Know If Soil Contains Living Things?
#
# === Cluster 111 (size=1382) ===
# Keywords: shamba, use, weeds, prepare, planting
# Meta: 1.0
# Sample questions:
#   - Thanks Rose Is It A Must 4 Me To Dig Or Can I Spray The Shamba To Kill Weeds
#   - WHEN WE TOPTRES WE MUST MAKE ANY WEEDS OUT OF THE SHAMBA:
#   - what is the maximum yield afarmer can get in aecre of shamba.
#   - IN ASLOPY SHAMBA HOW CAN I USE IT
#   - A farmer asks: I Hv Planted Btroots But My Shamba Is Full Of Broadleaf Weeds, Whch Is The Best Weedskiller 2 Use 2 Reduce Wids B4 I Start Widdng Reply Q270 followed by your response.
#
# === Cluster 112 (size=1449) ===
# Keywords: tools, farm, tool, use, garden
# Meta: 7.0
# Sample questions:
#   - WHA is the use of the following tool and equipmen TINSNIPS .WOOD RASP CHIPPING HAMMERS
#   - Why Is It Impotant To Maintain Farm Tools and equipments ?
#   - Which Tool Can I Use
#   - Wat z de use of a rake?
#   - state the difference between a farm tool and a farm implement.
#
# === Cluster 113 (size=905) ===
# Keywords: plantation, farming, plantations, good, start
# Meta: 4.0
# Sample questions:
#   - How cn 1 control "mabati"in de plantation?
#   - hw can i prune da plantations
#   - how many money use by the wefarm during plantation?
#   - How Can Sugar Plantations Be Maintained Locally?
#   - I wanna start matooke plantation how do i start and how i end.
#
# === Cluster 114 (size=694) ===
# Keywords: organic, farming, matter, soil, importance
# Meta: 1.0
# Sample questions:
#   - Ask question wat are te importance of organic matter in te soil
#   - WHAT IS ORGANIC FARMING.
#   - Disadvantages of organic farming
#   - what is the best organic farming practice
#   - My question was about organic farming ,method's and benefits that same one can get from it
#
# === Cluster 115 (size=494) ===
# Keywords: npk, use, apply, applied, meaning
# Meta: 1.0
# Sample questions:
#   - what is NPK in full?
#   - what is NPK in full
#   - how i can i use npk
#   - what does npk mean
#   - What npk in full?
#
# === Cluster 116 (size=577) ===
# Keywords: foliar, folia, fertilizer, feed, best
# Meta: 1.0
# Sample questions:
#   - give meaning of the term (foliar) fertilizer
#   - what is the foliarfeed?
#   - what is afoliar fertilizer?
#   - at which time foliar is aplied
#   - lakini iyo folier n liquid
#
# === Cluster 117 (size=900) ===
# Keywords: sheeps, trimming, hoof, cut, wool
# Meta: 3.0
# Sample questions:
#   - What can i use to trimme hooves
#   - IHAVE GOT SOME SHEEPS AND THERE HAVE STARTED WORNING OUT WHAT SHOULD I DO.
#   - WHat is the function of tail of acow and why are they tall
#   - what is a trimming knife?
#   - which tool is used for hoov triming
#
# === Cluster 118 (size=525) ===
# Keywords: dania, long, does, market, mature
# Meta: 4.0
# Sample questions:
#   - I Would like to know about dania.
#   - which soil is best for growing dania
#   - Is it a must that you raise a land when planting dani
#   - Where can i buy Dania seeds and who buys them ?
#   - how long will dania take to get ready
#
# === Cluster 119 (size=854) ===
# Keywords: urea, use, apply, fertilizer, mix
# Meta: 1.0
# Sample questions:
#   - can someone mix urea and CAN
#   - ; Can Urea Ferterizer Be Used For Planting?
#   - C.A.N AND UREA which is the best for top dreessing
#   - what nutrients does urea add to the soil?
#   - we put can/urea after how long.
#
# === Cluster 120 (size=457) ===
# Keywords: nitrogenous, phosphate, phosphorus, fertilizer, fertilizers
# Meta: 1.0
# Sample questions:
#   - Which Type Of Phospate Should Be Applied During Planting
#   - which is the x-stics of nitrogeneous fertiliser?
#   - Why is it not recommended to apply nitrogenous fertilizer at the time of planting.
#   - What is the use of Di Ammonium Phosphate.
#   - state 3 examples of phosphatic fertilizer
#
# === Cluster 121 (size=475) ===
# Keywords: nitrogen, soil, cycle, lost, bacteria
# Meta: 1.0
# Sample questions:
#   - what are the uses of nitrogen en da soil
#   - How can i reduce on nitrogen
#   - HOW IS CARBON DIOXIDE LOST FR0M DA SOIL
#   - E Which can i apply to fix nitrogen in the soil? thx.
#   - E .how can i improve on nitrogen in de garden?
#
# === Cluster 122 (size=1014) ===
# Keywords: simsim, sim, price, kg, grow
# Meta: 5.0
# Sample questions:
#   - How much is the kg of simsim?
#   - may i no the price of simsim
#   - How Long Does Simsim Take To Germinate And Conditions For Germination
#   - wht is the price of sim-sim
#   - Gdmng? In Mbarara,bushenyi And Rukungiri Where Can I Get Sim Sim?
#
# === Cluster 123 (size=473) ===
# Keywords: apply, applied, stage, time, planting
# Meta: 1.0
# Sample questions:
#   - s ,at what stage in height can I apply CAN
#   - How do we apply CAN
#   - how can I apply in 100hc
#   - how a my going 2 apply t
#   - .I am already applied match 3 but no positive response .tell me a better on
#
# === Cluster 124 (size=470) ===
# Keywords: hilly, terraces, areas, terrace, farming
# Meta: 4.0
# Sample questions:
#   - E which type of graezing which is good to use n hilly places
#   - What Is The Reason Why People Carry Out Terracess Method In There Shamba Than Contour Farming,?
#   - What type of farming is sultable in hilly areas
#   - Apart from mulching agood farmer can use terracing methord in hilly areas
#   - Wich types is it couple or slope
#
# === Cluster 125 (size=1248) ===
# Keywords: afarmer, afarm, start, wefarm, want
# Meta: 10.0
# Sample questions:
#   - to afarmer 0792583643
#   - Give the examples of afarm
#   - How much money do we start afarm
#   - Who Is Afarmer?
#   - what is afarm tool?
#
# === Cluster 126 (size=616) ===
# Keywords: swamp, swampy, area, areas, swamps
# Meta: 4.0
# Sample questions:
#   - Is't good to reclaim the swampy area
#   - What is swamp reclaimation?
#   - government is doing well or bad for taking our swamps?
#   - Which type of seed you can grow in swampy areas?
#   - gve me 5 advantages of swamps to pple? 0779010076
#
# === Cluster 127 (size=724) ===
# Keywords: biology, energy, living, biotic, things
# Meta: -1.0
# Sample questions:
#   - Can you give me an idea about bioügas
#   - wat is biology?
#   - What is biology mean?
#   - You Gave Mi Awrong Answer What Is Biophy
#   - What is entomology.
#
# === Cluster 128 (size=1376) ===
# Keywords: season, seasons, year, start, best
# Meta: 8.0
# Sample questions:
#   - what is the name of this season?
#   - whow can i know that the season is ready
#   - and in which seasons is the bert?
#   - My plan for this season is: (1.Solarsystem) ä2.smartphoneñ Ä3.good lifeÑ (4.bed) ä5.houserepairñ?.
#   - n what is the best season for malching?
#
# === Cluster 129 (size=464) ===
# Keywords: machine, cutter, hutch, chaff, cost
# Meta: 7.0
# Sample questions:
#   - lam asking tha can you give the procedure of taking care from hutching up to 6 mounths
#   - Samuel ask,what is the cost of splaying machine?
#   - How much is jafcuter which is mechanicals use
#   - what's the price of a new grinding machine wih 2 or3 pistons of the best quality
#   - hi guys how much does achaff cutter costs to buy
#
# === Cluster 130 (size=561) ===
# Keywords: garden, kitchen, prepare, gardens, gardening
# Meta: 4.0
# Sample questions:
#   - Which kind of garden?
#   - What shld we eat in thd gardens b4 they are ready?
#   - HOW CAN I SPARE TIME FOR MY GARDEN COR IHAVE MUCH RESPOBILITY?
#   - WAT ARE LIMITATIONS OF KITCHEN GARDENING?
#   - WHERE DO I FIND KITCHENS
#
# === Cluster 131 (size=503) ===
# Keywords: weevils, weevil, control, osama, best
# Meta: 2.0
# Sample questions:
#   - how can iprevent weevils.
#   - which is the best medicine of killing stokeborers and weevils
#   - what effect of wevils can give us
#   - what is the best way of keeping grains safe from weevils apart from use of chemicals
#   - how can weprevent kukurik:weevils inmaise
#
# === Cluster 132 (size=610) ===
# Keywords: vanilla, price, kg, kilogram, cost
# Meta: 5.0
# Sample questions:
#   - May I know the cost of vanilla?
#   - what is the price of vanilla
#   - How Much Is Vanilla
#   - Mbuuza; how much is one kilogram of vanilla?
#   - How Much Is A Kgm Of Vanilla
#
# === Cluster 133 (size=1065) ===
# Keywords: parasite, parasites, internal, external, control
# Meta: 2.0
# Sample questions:
#   - How can i prevent parasites
#   - Nne day after showhing signs.How can i prevent internal parasites?
#   - what is the observable signs of internal parasites and its quick control
#   - Outline examples of external parasite
#   - What are ectoparasites?
#
# === Cluster 134 (size=877) ===
# Keywords: production, quality, improve, increase, produce
# Meta: 3.0
# Sample questions:
#   - HOW HIGH SHLD MY STORE BE
#   - , passion to produce good production! What's the requirement
#   - The importance of table making is for good production and easy management practises
#   - How do i get quality products
#   - How will i improve production of millk in my farm??
#
# === Cluster 135 (size=431) ===
# Keywords: arsenal, man, chelsea, vs, liverpool
# Meta: 10.0
# Sample questions:
#   - whats your prediction LIVERPOOL VS MANUTD?
#   - how is man u city and arsenal
#   - can this first 11 win liverpool today Degea ,Bissaka ,Maguire ,Lindelf Luke Shaw Mac Tominay Fred ,Pogba ,Fernandes ,Rashford ,Martial ?
#   - Who took the 2018 world cup for today ?
#   - How did the match between arsenal and Chelse
#
# ...
#   - What is the use of fungicide in cabbegge growing
#
# === Cluster 169 (size=474) ===
# Keywords: mites, mite, spider, control, red
# Meta: 2.0
# Sample questions:
#   - what is the best bait to mix with redcat? wamekataa omena.
#   - Which chemicals r best for kiling mites(some dudus that attach themselves around the eyes)
#   - Does Mites Have Effect To Human Health?
#   - Which insectiside am i supposed to use to kill an anti hill and how much is it
#   - Which Medicine For Red Spider
#
# === Cluster 170 (size=812) ===
# Keywords: coughing, cough, medicine, injection, flue
# Meta: -1.0
# Sample questions:
#   - I met a person with huge legs but he is very healthy. which disease might he is suffering from?
#   - Which Type Of Injection Are Used
#   - what are methods used to control liuer flukes
#   - PLIZ I WOULD LIKE TO KNOWN THE CURE FOR COUGH DISEASE
#   - Which medicine can i give a come that goes on coughing after being treated by za Dr.
#
# === Cluster 171 (size=1026) ===
# Keywords: blood, stomach, hair, acow, stool
# Meta: nan
# Sample questions:
#   - BLOOD STAINED DROPPINGS INDICATES
#   - Simon asks: My newly born litre is dying when is not yet develope the hairs. What could be the cause? Reply Q3 followed by your response. optout stop 6333
#   - Can it die instantly or after sometime
#   - my 2 kids died last month.they started with general weakness,then diarrhoea. They were injected by vet then gave them S-dime but they still died.
#   - how to inserminate acow
#
# === Cluster 172 (size=537) ===
# Keywords: mating, natural, period, mate, acow
# Meta: nan
# Sample questions:
#   - Wat z pologamy?
#   - what is natural mating?
#   - what is meant by hand mating?
#   - Is there need to boost it for mating?
#   - What is mating in the farm.
#
# === Cluster 173 (size=720) ===
# Keywords: land, farming, piece, acre, small
# Meta: 4.0
# Sample questions:
#   - What should one consider when selecting agood land for farming?
#   - why isnt that after harvesting a land is left for some time and for hw long
#   - ithak three hictar of land
#   - Given that I have 0.1 acre of land,what farming project shall I carry out to uplift myself economically?
#   - State how the farmer acquire their land ?
#
# === Cluster 174 (size=1626) ===
# Keywords: ovacado, grafted, market, ovacados, avocadoes
# Meta: 5.0
# Sample questions:
#   - what is best variety of ovacado grown in kericho
#   - can watermeloane do well at webuye.
#   - What can i do 4tomatoz 2 ripen earlier.
#   - What are the products got from ovacado?
#   - Which ovacado variety is good for market?
#
# === Cluster 175 (size=1372) ===
# Keywords: spacing, space, planting, pine, proper
# Meta: 4.0
# Sample questions:
#   - Alfred asks: QWhere do i get seeds Pine?And How To Maneg
#   - what is the spacing when planting or farming
#   - which is the right spacing when planting maembe?
#   - GIVE ME SPACING FROM ONE STOOL TO ANOTHER
#   - DOES THIS METHOD ALSO MATTER IN TERMS OF SPACE?
#
# === Cluster 176 (size=972) ===
# Keywords: sugar, uganda, price, kg, vanilla
# Meta: 5.0
# Sample questions:
#   - How much is a kg of sugar?
#   - i want 2 kno hw 2 grow sugar cain
#   - n hw much is sugar in kampala
#   - TM eg SUGARBABY
#   - thanks. who have jogoos 4 sale n how much am around kamulu,Nairobi county.
#
# === Cluster 177 (size=527) ===
# Keywords: pilipili, hoho, best, variety, pili
# Meta: 4.0
# Sample questions:
#   - where do I get info how to farm pilipili
#   - which is the best variety of pilipili hoho
#   - which variaty of pili pili is the best
#   - rio grande,magrop and f1 which one is good in rain
#   - How can i improve the production of hoho
#
# === Cluster 178 (size=769) ===
# Keywords: young, apig, acow, agoat, ayoung
# Meta: 3.0
# Sample questions:
#   - What is the name given to ayoungones of ahen?
#   - How do we call ahouse of agoat and asheep
#   - wat dizz of agoat
#   - What is the youngone of agoat
#   - why is apig called ascavenger?
#
# === Cluster 179 (size=433) ===
# Keywords: times, age, old, long, day
# Meta: 3.0
# Sample questions:
#   - WHO IS AGE?
#   - a normal human being supposed to pollute how many times per day?
#   - HOW CAN AFAMALE TICT PRODUCE?
#   - What A Da Xtics Of Apig Which Is About 2 Produce
#   - Hw does afung produce
#
# === Cluster 180 (size=555) ===
# Keywords: dry, season, wet, areas, area
# Meta: 8.0
# Sample questions:
#   - What of in dry season?
#   - durng the months when we exprience wet seasonz.
#   - when do wet season begins?
#   - How can someone survive within this dry season
#   - WHY SHOUID WE CONSERVE WET LANDS
#
# === Cluster 181 (size=445) ===
# Keywords: dry, drying, causes, matter, dried
# Meta: 1.0
# Sample questions:
#   - what is drycow therapy
#   - What causes wet dreems?
#   - n. Wat is drying off
#   - Wat z dry mass ?
#   - but it dries up after sometime
#
# === Cluster 182 (size=1860) ===
# Keywords: grow, vanila, planting, planted, growing
# Meta: 4.0
# Sample questions:
#   - What procedures do i follow when am planting vanila because of starting the project.
#   - What is the difference between highland and lowland regions?
#   - WHAT IS GOOD FOR GROWING IN THIS SEASON
#   - DK and MTK which is the best for growing?
#   - How can farmer predict the best planting in kericho
#
# === Cluster 183 (size=808) ===
# Keywords: seedling, seedlings, seed, seeds, selection
# Meta: 4.0
# Sample questions:
#   - What is seedling and seed
#   - Iam kifuse what is seed selection?
#   - #What Is The Different Between Seeds Ana Seedlings
#   - n what is difference btn seedlings and seeds
#   - ASK ME HOW CAN I HELP MY SEEDLING' WHICH ARE DRYING UP IN MY BED
#
# === Cluster 184 (size=856) ===
# Keywords: seeds, seedlings, ovacado, seed, seedling
# Meta: 5.0
# Sample questions:
#   - n.what is the cost of vanila seedlings ?
#   - If ineed seed what can ido
#   - WHERE CAN I GET MARKET FOR FRENCH BEANSEEDS
#   - Which seed is taking one week
#   - _i need ready grafted ovacado seeds within NANDI 'sms to 0726226418
#
# === Cluster 185 (size=1098) ===
# Keywords: f1, gloria, does, cost, seeds
# Meta: 5.0
# Sample questions:
#   - can this variety withstand long distance market? Where can I get it? And is it F1?
#   - How much is 25g of Gloria f1?
#   - what benefit does kiboko f1 have over common Copenhagen
#   - How much does sukari F1 cost in the farm
#   - How much is F1 seeds Where can I find it What quantity of seeds will finish an accre
#
# === Cluster 186 (size=985) ===
# Keywords: start, money, rich, poverty, business
# Meta: 6.0
# Sample questions:
#   - which kind of busness i can do in butere khwisero area!?
#   - what is the minimum amount to have for astart
#   - Jhve adebt of 5000000 what can j do to pay dat money in six months
#   - can a rabbith earn me with an income
#   - staying in adry season wiz poverty in de pocket wich cheap business can i work in order 2 succeed.
#
# === Cluster 187 (size=10516) ===
# Keywords: farm, farming, farmer, farmers, agriculture
# Meta: 9.0
# Sample questions:
#   - Can i get farmers in murang'a
#   - What are farm structures?Q
#   - REQUEST"Can my fellow farmers sisters =& brothers HELP get a smartphone ?? Or loan from WEFARM,ill be happy =&GOD BLESS U ALL (ROTICH ).
#   - What agricultural courses can i do with a c4 in agric,p8 in eng and f9 in math.
#   - WHAT ARE THE DYNAMICS &STATICS OF OPTICS AGRICULTURE?
#
# === Cluster 188 (size=655) ===
# Keywords: start, want, requirements, need, started
# Meta: 4.0
# Sample questions:
#   - HOW WILL I START
#   - Please update me azn naona Niko na ujuzi kidogo nijiunge nanyi what are the requirements one should have
#   - I wat 2 start to graizing pgs but hw can i start nw?
#   - what con i do to are good fram?
#   - its well I will start soon and where will I get u.
#
# === Cluster 189 (size=550) ===
# Keywords: luganda, use, runyankole, runyankore, english
# Meta: 10.0
# Sample questions:
#   - Is it true that bahima people speak luganda
#   - i understand english most than luganda 6333
#   - Please sir may i truslet my question in luganda.
#   - E I Understand Luganda than any other languages
#   - What is coat of arm in luganda
#
# === Cluster 190 (size=593) ===
# Keywords: english, language, change, use, want
# Meta: 10.0
# Sample questions:
#   - Which language do I use help me know
#   - Apart from English,which other languages are used in dis group.Reply
#   - which method may I use to ask questions in local language e.g Runyankole
#   - E how to ask in english
#   - can u change for me the language
#
# === Cluster 191 (size=440) ===
# Keywords: keeping, maintain, poutly, preserve, poutrly
# Meta: 3.0
# Sample questions:
#   - ABOUT BII KEEPING
#   - what is doking?
#   - What causes poutly voice in poutly
#   - how to keep
#   - Is their anyother apart from caljay
#
# === Cluster 192 (size=614) ===
# Keywords: afforestation, defforestation, meaning, wat, iz
# Meta: 8.0
# Sample questions:
#   - What is defforestation and give 3 advantages of defforestation?
#   - What is afforestation as practiced in farming?
#   - What is prodetors?
#   - What is re-afforestation? Gud mrng? Reply Qn2 folowed by yo response.
#   - WHAT IS DEFFORESTATION. GD EVN'NG 2 U ALL! REPLY ME.
#
# === Cluster 193 (size=408) ===
# Keywords: sms, stop, messages, want, send
# Meta: 10.0
# Sample questions:
#   - I het ure sms
#   - Sms ina cost how much?
#   - Which help can l help with you my sms has over
#   - How do i stope wefarm sending me sms.
#   - I WANT TO STOP THIS MESSAGES
#
# === Cluster 194 (size=532) ===
# Keywords: group, leave, want, quit, opt
# Meta: 10.0
# Sample questions:
#   - How can i leave the group?
#   - I want to leave this forum am tired of it What can i do ?
#   - I want to left that group
#   - Please i stop my membership
#   - how can you opt out
#
# === Cluster 195 (size=707) ===
# Keywords: long, answer, wait, waiting, question
# Meta: 10.0
# Sample questions:
#   - UESTION, Am eagerly waiting
#   - how fast do you give answers?
#   - for how long am i waiting for an answer?
#   - How long do you take to answer QS?
#   - E why do you take long to reply?
#
# === Cluster 196 (size=1220) ===
# Keywords: wefarm, located, headquarters, headquaters, head
# Meta: 9.0
# Sample questions:
#   - where Are Headquarters Of Wefarm Located.
#   - where did the headquater of wefarme?
#   - bt wea is wefarm head ofice located?
#   - Hw to get insurance in wefarm programme
#   - where does wefarm found?
#
# === Cluster 197 (size=689) ===
# Keywords: wefarm, want, leave, stop, quit
# Meta: 10.0
# Sample questions:
#   - i withdrew frm wefarm and now am in digifarm plz
#   - BLOCK ME FROM WEFARM
#   - WEFARM hw can i do while it rotten
#   - why would I die if I left wefarm.
#   - ,how Can I Log Out From Wefarm?
#
# === Cluster 198 (size=765) ===
# Keywords: wefarm, job, wafarm, work, wifarm
# Meta: 9.0
# Sample questions:
#   - where do i get the job from wefarm?
#   - are there job vacancies in wefarm
#   - N HOW CAN I GET A JOB IN WEFAM
#   - ,how can i become self employed after aquiring knowledge from wefarm
#   - how can weifarm help
#
# === Cluster 199 (size=473) ===
# Keywords: wefarm, founder, did, started, start
# Meta: 9.0
# Sample questions:
#   - wen did wefarm started,
#   - what is the name of a person who started wefarm?
#   - Briefly explain for me the origin of Wefarm?
#   - Ronald asks: Hi Wefarm. Who Is The Founder Of Wefarm And Were Are U Locaited. Reply Q8 followed by your response.
#   - , WHERE IS WEFARM ORIGINATE?
#
# === Cluster 200 (size=489) ===
# Keywords: jesus, moses, day, bible, today
# Meta: 10.0
# Sample questions:
#   - LAST BOOK IN BIBLE?
#   - Julia anauliza;Who was the mum of Jesus?
#   - Who was the father of all belivers
#   - Which day is it rianing
#   - Moses asks: why don't u want 2 receive my messages?
#
# === Cluster 201 (size=529) ===
# Keywords: names, ur, know, wat, want
# Meta: 10.0
# Sample questions:
#   - What is you name
#   - E who is this?
#   - what do we call this?
#   - What a their names?
#   - what is your real name plz help me ur nomber
#
# === Cluster 202 (size=472) ===
# Keywords: problem, solution, solve, wrong, solutions
# Meta: 10.0
# Sample questions:
#   - :what is your problem now?
#   - nwwhat could be the solution
#   - there is an indivication problem
#   - Wat is your problem papa
#   - WHAT IS THE PROBLEM?
#
# === Cluster 203 (size=832) ===
# Keywords: insermination, artificial, insamination, advantages, natural
# Meta: 3.0
# Sample questions:
#   - What is artificial inthermination?
#   - Why do farmers carry out artificial insermination?
#   - WHAT ARE ADVANTAGES OF ARTIFIAL INSERMINATION?
#   - what are the disadvertanges of artifitial inserminations?
#   - What is artificial insermination?
#
# === Cluster 204 (size=1366) ===
# Keywords: price, cost, market, kg, sack
# Meta: 5.0
# Sample questions:
#   - how much is one kilo of pilipili hoho cost
#   - niko na shamba for lease 10ha at 10k each if intrested kam for it
#   - at how much?, coz I'm at Taita county
#   - What is aprice of asprayer
#   - who's buying malenge in Bomet, ndamichonik?
#
# === Cluster 205 (size=414) ===
# Keywords: pork, meat, kg, price, 1kg
# Meta: 5.0
# Sample questions:
#   - Hw mch z a kg ov beef?
#   - n. How much is a kilogram of pork? Hey. Good evng,i lav u all
#   - Wat z de price of pork in dis lockdown?
#   - which is da price of pork these days i want 20kgs for my birthday party i am in nkungu kazo
#   - hao much a kg pork
#
# === Cluster 206 (size=423) ===
# Keywords: bomet, town, boran, east, central
# Meta: 5.0
# Sample questions:
#   - What is boffa explaine atleaxt nielewe
#   - What is a bos indicus?070181040
#   - #@ jackson am in bomet please.I don't know where to response when a quiz is asked.Thanks
#   - Who Will I Find at Bomet
#   - Where can i get dyasini?
#
# === Cluster 207 (size=411) ===
# Keywords: did, thanks, got, exactly, ok
# Meta: 5.0
# Sample questions:
#   - Where Will I Get
#   - where can I find it
#   - Where do i get particularly?
#   - Where can iget it? Is it free or ibuy?
#   - , where do we get you?
#
# === Cluster 208 (size=710) ===
# Keywords: nakuru, county, narok, baringo, town
# Meta: 5.0
# Sample questions:
#   - Any bdy who leave at or near Narok to tell me the trut about imbogishi land<113>
#   - WHERE ARE BECAUSE I AM FOUND IN BARINGO.
#   - imajne am in tongaren and i dont know where 2 find
#   - where can I GET TRAING OF AI WHITIN NAKURU
#   - lam in narok where do get afamer who is narok to sell to me, cos those in the market are sick
#
# === Cluster 209 (size=448) ===
# Keywords: bungoma, county, office, agrovet, town
# Meta: 5.0
# Sample questions:
#   - Maraka Ward, Bungoma County, Webuye Town.
#   - What is the meaning of bunidig
#   - i am in bungoma region.
#   - How many people come from BUNGOMA?
#   - What about bungoma county
#
# === Cluster 210 (size=994) ===
# Keywords: write, meaning, npk, ful, bbw
# Meta: 1.0
# Sample questions:
#   - What z k.c.c in ful
#   - Who is in charge of I.E.B.C
#   - Wat iz UMEME in full?
#   - what is strigger ssp ?
#   - what z CAN in full
#
# === Cluster 211 (size=621) ===
# Keywords: want, need, help, plz, got
# Meta: 10.0
# Sample questions:
#   - did i get?
#   - How Do I Get U
#   - HOW CAN GET?
#   - what can i do to get that
#   - how to get it
#
# === Cluster 212 (size=959) ===
# Keywords: love, friends, hello, hi, guys
# Meta: 10.0
# Sample questions:
#   - What is love?Damu ne q3.
#   - How are you my teacher
#   - how are you doing over there?
#   - Benja says: What causes love.
#   - wat is love!
#
# === Cluster 213 (size=1035) ===
# Keywords: need, lover, wife, marry, want
# Meta: 10.0
# Sample questions:
#   - S hi! I'm sh surching a boyfrend please requst me
#   - Maintance Man Careful And Truth Love
#   - I am ask who is ready for relationship to sendi contact woman
#   - E I need a fiance pliz reply i am monic
#   - Hw can i get a lover at my stage of s2 through wefarm.
#
# === Cluster 214 (size=1091) ===
# Keywords: wat, shall, tried, ok, going
# Meta: 10.0
# Sample questions:
#   - I hv tried but it has failed wat else can i use?
#   - How will i do it
#   - How do u do too.
#   - How can do it?
#   - so tel me what to do
#
# === Cluster 215 (size=1022) ===
# Keywords: wat, hw, iz, wht, meaning
# Meta: 10.0
# Sample questions:
#   - i lav u bebi
#   - e to culitevete becoz imay ruse amarket again wht cn i do?
#   - What Z Famentation?
#   - -HWZ U?
#   - What z the whether there
#
# === Cluster 216 (size=784) ===
# Keywords: ni, nini, en, poa, nee
# Meta: 10.0
# Sample questions:
#   - imenisaedia sana thanks
#   - what is the prince of a hoe in kiruhura?
#   - E Bikunyumira bitya Mr. Oen? Am just proud of my work.
#   - s asande dorkars.
#   - ingoam teta borowet kolionen?

# %%
# Map clusters to metaclusters based on ChatGPT feedback. 
# Input the prompt found in /notes/LLM_prompts.txt followed by the output of summarize_clusters(), keeping within character limit (I submitted chunks of 40-50 clusters at a time)
# Check for NaNs-- there were about 3 clusters missing that I had to manually add back in from the intial assignments saved in notes/LLM_clusterassignments_unlabeled.txt

cluster_to_meta = {
    **dict.fromkeys([0, 12, 15, 16, 52, 53, 54, 57, 58, 59, 60, 83, 84, 87, 88, 91, 92, 98, 101, 108, 113, 118, 124, 126, 130, 137, 147, 151, 173, 175, 177, 182, 183, 188], 4),  # Planting & Growth
    **dict.fromkeys([1, 7, 9, 13, 34, 35, 45, 46, 47, 48, 85, 99, 107, 131, 133, 140, 144, 150, 165, 166, 168, 169], 2),  # Pests & Disease
    **dict.fromkeys([2, 3, 4, 5, 6, 10, 11, 14, 24, 26, 27, 29, 32, 55, 56, 81, 90, 95, 96, 102, 103, 117, 134, 143, 146, 156, 162, 171, 172, 178, 179, 191, 203], 3),  # Animal Husbandry
    **dict.fromkeys([8, 19, 20, 21, 22, 23, 33, 39, 40, 41, 43, 44, 49, 50, 65, 69, 75, 82, 94, 106, 110, 111, 114, 115, 116, 119, 120, 121, 123, 141, 142, 149, 153, 154, 155, 159, 164, 181, 210], 1),  # Soil, Fertilizer, & Animal Feed
    **dict.fromkeys([74, 122, 132, 148, 184, 185, 204, 205, 206, 207, 208, 209, 176, 174], 5),  # Markets
    **dict.fromkeys([17, 18, 71, 72, 186, 167, 163], 6),  # Finance & Loans
    **dict.fromkeys([25, 28, 31, 42, 76, 86, 93, 100, 112, 129], 7),  # Farming Equipment & Materials
    **dict.fromkeys([30, 51, 97, 109, 128, 138, 180, 192], 8),  # Weather & Environment
    **dict.fromkeys([37, 61, 62, 67, 77, 80, 89, 139, 145, 187, 196, 198, 199], 9),  # Wefarm Platform
    **dict.fromkeys([36, 38, 63, 64, 68, 70, 73, 78, 79, 125, 135, 136, 152, 157, 158, 160, 161, 189, 190, 193, 194, 195, 197, 200, 201, 202, 211, 212, 213, 214, 215, 216], 10),  # Personal Communication
    **dict.fromkeys([66, 104, 105, 127, 170], -1)  # Uncategorized
}
unlabeled_df['meta_label'] = unlabeled_df['cluster'].map(cluster_to_meta)

# %%
meta_titles = {
    -1: "Uncategorized", 
    1: "Soil & Fertilizer", 
    2: "Pests & Disease", 
    3: "Animal Husbandry", 
    4: "Planting & Growth", 
    5: "Markets", 
    6: "Finance & Loans", 
    7: "Farming Equipment & Materials", 
    8: "Weather & Environment", 
    9: "Wefarm Platform",
    10: "Personal Communication"
}
# Ensure all -1 clusters have meta_label = -1
unlabeled_df.loc[unlabeled_df['cluster'] == -1, 'meta_label'] = -1

# Map meta_label to titles
unlabeled_df['meta_label_title'] = unlabeled_df['meta_label'].map(meta_titles)

# Fill any unmapped values just in case
unlabeled_df['meta_label_title'] = unlabeled_df['meta_label_title'].fillna("Uncategorized")

# %%
unlabeled_df['meta_label_title'].value_counts()
# Out:
# meta_label_title
# Uncategorized                    162234
# Animal Husbandry                  92409
# Soil & Fertilizer                 89456
# Personal Communication            72921
# Planting & Growth                 61526
# Pests & Disease                   50452
# Wefarm Platform                   41906
# Markets                           24591
# Farming Equipment & Materials     21266
# Weather & Environment             14615
# Finance & Loans                   11772
# Name: count, dtype: int64

# %%
unlabeled_df.loc[unlabeled_df['meta_label'].isna(), 'cluster'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
quick_save_file(data_dir = data_dir, 
                filename = "unlabeled_clustered_df.parquet", 
                obj = unlabeled_df
               )
# Out:
# unlabeled_clustered_df.parquet already exists. Skipping save.

# %%
# Re-run summarize_clusters to get updated meta labels
# metacluster_preview(unlabeled_summary, 
#                     metacluster_num=1,
#                     meta_titles=meta_titles)

# %% [markdown]
# ### Figure Generation

# %%
## Loads previously saved model and dataframe ready for visualization
# unlabeled_clusterer = joblib.load(os.path.join(data_dir, "unlabeled_hdbscan_model.pkl"))
# unlabeled_df = pd.read_parquet(os.path.join(data_dir, "unlabeled_clustered_df.parquet"))

# %%
umap_2d = umap.UMAP(
    n_components=2,
    n_neighbors=50,
    min_dist=0.1,
    metric="cosine",
    random_state=42
)

embedding_2d = umap_2d.fit_transform(list(unlabeled_df['embedding']))

quick_save_file(data_dir, "unlabeled_umap_2d_embedding.npy", embedding_2d)

# %%
minimal_df = unlabeled_df[['question_id', 'meta_label', 'cluster']]
minimal_df = minimal_df.copy()
minimal_df['umap_x'] = embedding_2d[:, 0]
minimal_df['umap_y'] = embedding_2d[:, 1]

# %%
# Save question clusters with 2D embeddings locally for merging with full dataset later
# save_question_clusters(df = unlabeled_df,
#                        embedding_2d = embedding_2d,
#                        topic = "unlabeled")
# Out:
# Saved ../data/question_clusters_unlabeled.parquet (643148 rows)

# %%
minimal_df['question_id']
# Out:
# 0          4107267
# 1          4107349
# 2          4107354
# 3          4107424
# 4          4107802
#             ...
# 643143    59086651
# 643144    59086652
# 643145    59086816
# 643146    59086934
# 643147    59087077
# Name: question_id, Length: 643148, dtype: object

# %%
import plotly.express as px

# --- Build a combined column "<id> — <title>" ---
minimal_df['meta_label_title'] = minimal_df['meta_label'].astype(int).map(meta_titles)
minimal_df['meta_label_full'] = (
    minimal_df['meta_label'].astype(int).astype(str) 
    + " — " 
    + minimal_df['meta_label_title']
)

# Ensure ordered categories based on numeric sort
ordered_labels = sorted(minimal_df['meta_label'].unique())
ordered_full = [
    f"{i} — {meta_titles[i]}" for i in ordered_labels
]
minimal_df['meta_label_full'] = minimal_df['meta_label_full'].astype('category')
minimal_df['meta_label_full'] = minimal_df['meta_label_full'].cat.set_categories(
    ordered_full, ordered=True
)

# --- Color map (must map to full labels!) ---
color_map = {
    f"{i} — {meta_titles[i]}": col 
    for i, col in {
        -1: "black",
         1: "#1f77b4",
         2: "#ff7f0e",
         3: "#2ca02c",
         4: "#d62728",
         5: "#9467bd",
         6: "#8c564b",
         7: "#e377c2",
         8: "#7f7f7f",
         9: "#bcbd22",
        10: "#17becf",
    }.items()
}

# --- Plot ---
fig = px.scatter(
    minimal_df,
    x="umap_x",
    y="umap_y",
    color="meta_label_full",
    color_discrete_map=color_map,
    category_orders={"meta_label_full": ordered_full},
    hover_data=["question_id", "cluster", "meta_label"],
    opacity=0.8
)

fig.update_layout(
    legend_title_text="Meta-Cluster",
    legend=dict(itemclick="toggleothers", itemdoubleclick="toggle"),
    xaxis=dict(scaleanchor="y", scaleratio=1),
    yaxis=dict(scaleanchor="x", scaleratio=1),
    width=800,
    height=800,
)

fig.update_traces(
    selected=dict(marker=dict(opacity=1, size=8)),
    unselected=dict(marker=dict(opacity=0.12))
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import plotly.express as px
#       3 # --- Build a combined column "<id> — <title>" ---
# ----> 4 minimal_df['meta_label_title'] = minimal_df['meta_label'].astype(int).map(meta_titles)
#       5 minimal_df['meta_label_full'] = (
#       6     minimal_df['meta_label'].astype(int).astype(str)
#       7     + " — "
#       8     + minimal_df['meta_label_title']
#       9 )
#      11 # Ensure ordered categories based on numeric sort
#
# NameError: name 'minimal_df' is not defined

# %%
# Find rows where meta_label is NaN
nan_rows = minimal_df[minimal_df['meta_label'].isna()]
print(nan_rows['cluster'].value_counts())
print("Rows with NaN meta_label:")
print(nan_rows)
print(f"\nTotal NaNs: {len(nan_rows)}")
# Out:
# cluster
# -1      157906
#  145       421
# Name: count, dtype: int64
# Rows with NaN meta_label:
#        question_id  meta_label  cluster     umap_x    umap_y
# 12         4109374         NaN       -1  13.776208  5.050594
# 16         4110007         NaN       -1  12.304329  7.068155
# 18         4110239         NaN       -1  11.391359  7.172901
# 19         4110651         NaN       -1  10.782326  6.167444
# 21         4110944         NaN       -1   8.109047  9.294688
# ...            ...         ...      ...        ...       ...
# 643132    59085548         NaN       -1  12.981956  7.467135
# 643135    59085656         NaN       -1  12.977041  7.469586
# 643139    59086264         NaN       -1   5.015298  4.617218
# 643141    59086616         NaN       -1  14.219928  8.536251
# 643147    59087077         NaN       -1  16.646841  6.435987
#
# [158327 rows x 5 columns]
#
# Total NaNs: 158327

# %%
import pandas as pd
import plotly.express as px

# --- Compute centroids and cluster sizes ---
centroids = (
    minimal_df
    .groupby(["cluster", "meta_label"], as_index=False)
    .agg(
        umap_x=("umap_x", "mean"),
        umap_y=("umap_y", "mean"),
        size=("cluster", "count"),
    )
)

# --- Ensure meta_label is ordered ---
ordered_labels = sorted(centroids["meta_label"].unique())
centroids["meta_label"] = centroids["meta_label"].astype("category")
centroids["meta_label"] = centroids["meta_label"].cat.set_categories(
    ordered_labels, ordered=True
)

# --- Color map ---
color_map = {
    -1: "black",
    1: "#1f77b4", 2: "#ff7f0e", 3: "#2ca02c", 4: "#d62728",
    5: "#9467bd", 6: "#8c564b", 7: "#e377c2", 8: "#7f7f7f",
    9: "#bcbd22", 10: "#17becf",
}

# --- Uniformly scale all point sizes (e.g., 2× bigger) ---
scale_factor = 2.0
centroids["scaled_size"] = centroids["size"] * scale_factor

# --- Plot ---
fig = px.scatter(
    centroids,
    x="umap_x",
    y="umap_y",
    color="meta_label",
    color_discrete_map=color_map,
    size="scaled_size",
    size_max=120,   # ensures upper bound isn't clipped
    category_orders={"meta_label": ordered_labels},
    hover_data={
        "cluster": True,
        "meta_label": True,
        "size": True,
        "umap_x": ':.2f',
        "umap_y": ':.2f',
    },
)

fig.update_layout(
    title="Centroid Map of Clusters in 2D UMAP Space",
    width=800,
    height=800,
    legend_title="Meta-Cluster",
    xaxis=dict(scaleanchor="y", scaleratio=1),
    yaxis=dict(scaleanchor="x", scaleratio=1),
    legend=dict(
        itemclick="toggleothers",   # click highlights
        itemdoubleclick="toggle",   # double-click isolates
    ),
)

fig.update_traces(
    selected=dict(marker=dict(opacity=1)),
    unselected=dict(marker=dict(opacity=0.15))
)

fig.show()

# %%
print(meta_titles)
# Out:
# {-1: 'Uncategorized', 1: 'Soil & Fertilizer', 2: 'Pests & Disease', 3: 'Animal Husbandry', 4: 'Planting & Growth', 5: 'Markets', 6: 'Finance & Loans', 7: 'Farming Equipment & Materials', 8: 'Weather & Environment', 9: 'Wefarm Platform', 10: 'Personal Communication'}

# %% [markdown]
# ### Automated meta-clustering attempt
# (not successful)

# %%
from umap import UMAP
from sklearn.cluster import AgglomerativeClustering
import numpy as np

# Compute centroids
cluster_centroids = (
    unlabeled_df[unlabeled_df['cluster'] != -1]['embedding']
    .groupby(unlabeled_df['cluster'])
    .apply(lambda x: np.mean(np.vstack(x), axis=0))
)
centroids = np.vstack(cluster_centroids.values)

# Optional: reduce dimensionality before meta-clustering
umap_model = UMAP(n_components=2, metric='cosine', random_state=42)
centroids_2d = umap_model.fit_transform(centroids)

# Agglomerative clustering on reduced embeddings
meta_clusterer = AgglomerativeClustering(
    n_clusters=None,
    distance_threshold=0.55,
    linkage='average'
)
meta_labels_no_noise = meta_clusterer.fit_predict(centroids_2d)

# Map back to original clusters
meta_labels = dict(zip(cluster_centroids.index, meta_labels_no_noise))
meta_labels[-1] = -1
unlabeled_df['meta_cluster'] = unlabeled_df['cluster'].map(meta_labels)

# %%
for lbl, group in unlabeled_df.groupby("meta_cluster"):
    print("Number of Meta-clusters:", len(unlabeled_df['meta_cluster'].unique()))
    print(f"\n--- Meta-cluster {lbl} ---")
    print(group["cluster"].value_counts())
# Out:
# Number of Meta-clusters: 29
#
# --- Meta-cluster -1 ---
# cluster
# -1    22134
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 0 ---
# cluster
# 9     2667
# 13    1530
# 10     866
# 8      668
# 41     449
# 42     169
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 1 ---
# cluster
# 3     904
# 1     668
# 64    350
# 65    299
# 47    254
# 49    170
# 48    150
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 2 ---
# cluster
# 39    243
# 50    225
# 77    224
# 45    207
# 57    193
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 3 ---
# cluster
# 30    877
# 68    356
# 63    344
# 62    338
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 4 ---
# cluster
# 36    1995
# 34    1339
# 92     409
# 94     360
# 90     218
# 84     193
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 5 ---
# cluster
# 6     1687
# 18    1156
# 51     218
# 52     183
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 6 ---
# cluster
# 35    2578
# 87     443
# 91     199
# 93     187
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 7 ---
# cluster
# 31    2587
# 70     459
# 78     372
# 80     199
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 8 ---
# cluster
# 5     2287
# 11     985
# 71     364
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 9 ---
# cluster
# 76    509
# 85    185
# 74    162
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 10 ---
# cluster
# 23    3464
# 25    2048
# 4      917
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 11 ---
# cluster
# 24    626
# 43    176
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 12 ---
# cluster
# 20    5281
# 60     490
# 56     179
# 67     171
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 13 ---
# cluster
# 28    934
# 7     815
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 14 ---
# cluster
# 89    666
# 46    268
# 79    262
# 83    208
# 61    184
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 15 ---
# cluster
# 19    3248
# 17     753
# 38     304
# 58     246
# 53     158
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 16 ---
# cluster
# 14    930
# 15    526
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 17 ---
# cluster
# 12    4075
# 2      529
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 18 ---
# cluster
# 21    6342
# 66     401
# 59     326
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 19 ---
# cluster
# 69    853
# 29    568
# 0     542
# 44    411
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 20 ---
# cluster
# 16    1067
# 27     651
# 26     647
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 21 ---
# cluster
# 73    253
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 22 ---
# cluster
# 88    279
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 23 ---
# cluster
# 22    1379
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 24 ---
# cluster
# 37    204
# 40    185
# 55    165
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 25 ---
# cluster
# 33    1902
# 32    1026
# 86     453
# 82     241
# 81     173
# 75     164
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 26 ---
# cluster
# 72    547
# Name: count, dtype: int64
# Number of Meta-clusters: 29
#
# --- Meta-cluster 27 ---
# cluster
# 54    204
# Name: count, dtype: int64

# %%
for lbl, group in unlabeled_df.groupby("meta_cluster"):
    print(f"\n--- Meta-cluster {lbl} ---")
    print(group["Q_basic_clean"].sample(10).tolist())
# Out:
# --- Meta-cluster -1 ---
# ['what is tilling of the land', 'Wat are pleateaus ?', 'what is omnivorous', 'Aminah asks: How can i plan matooke? Reply Q25 followed by your response.', 'which Pesticides is the best for controling weevils', 'what is the meaning of the word brids', 'I dot knowe where do we get bt even me i dot where do you get', 'Is God real?', 'What can ido? Am apoutry farmer.', 'What Is The Causal Organism Of Anthrax']
#
# --- Meta-cluster 0 ---
# ['what is Soil leaching?', 'What is the BEST method of irrigation?', 'How Can I Now The Characteristics Of A Good Soil', 'What Is Soil Leaching?', 'How can soil gain its fertility?', 'discribe for me the proces of cleaning water in the farm', 'How often should I give it water', 'Where will I get a money maker water pumb machine and at how much, in kericho?', 'how the soil loose fertility in the soil', 'give 2 ways how soil is formed']
#
# --- Meta-cluster 1 ---
# ['which medicine are suitable 2 attack armyworm?', "E if some begins a rat farm do they have mar'kt?", 'i have aproblem of rats at my farm what can i do oba is there any one who knows any kind of medicine which i can use to kill dem plz hlp me?', 'I was answering questions asked by a farmer if predators can control cutworms', 'wayz of killing bed bag a part from using chemical', 'can i control the poison in water', 'how can i control parasites especially ticks,which is the best method?', 'which chemical can be used to spray in the bed to kill some parasits?', 'Which chemichels can i use kill rats in my store', 'What can i use to kill catapilers']
#
# --- Meta-cluster 2 ---
# ['Am asking what is cultivation', 'What is croprotation....', 'What are the advantages of mixed farming?', 'What z inter cropping?', "What's importance of primary cultivation", ', What is chlorosis?', 'wat iz shifthng cultivation', 'What is cultivation', 'What is ecology', 'What is meant by strip cropping']
#
# --- Meta-cluster 3 ---
# ['any farmer with ajob?', 'What if i grow green paper, which one is the best type to grow?', 'How much is martress six by six in tororo reply Q40', 'How Many Bgs Does 1 Acre Give, Side Bungoma.Kamukuywa', 'wat is use of red paperz ÄkamulaliÑ to a body ?', 'FACTOR OF PRODUCE', 'WHAT IS GREEN HOUSE?', 'Hw 2 grow redpaper', ',where can i get green house materials have made one with local materials but its not long lastng.', 'HOW CAN GET GREEN HOUSE']
#
# --- Meta-cluster 4 ---
# ['-goodnight men have no question today,', 'Clone 510 where do I find it', 'my answer?', 'Who is simon and denis', 'i neen poline number', 'May i have the contacts of julius please', 'What are U meaning?', 'E gd mrng my frnd', 'I want to help in answering questions', 'WHAT IS THE ANSWER?']
#
# --- Meta-cluster 5 ---
# ['Why is milk highly perishable', 'which mineral should i used to feed my culves', 'what does stokebores eat', 'What is milk stimulation?', 'which feed do l use for better production?', 'which is the best food during wining', '_Is it good to milk acow until the last mnth of givingbirth?', 'My dairygoat has miscarried with3and ahlf months, can I milk it?', 'Is it good to give more milk to acalf.', 'How can I be fat?']
#
# --- Meta-cluster 6 ---
# ['Is it better in my location at lessos in nandi county?', 'Where are the offices of Wefarm located.', 'how do we call etulla in english?', 'Where the office of wefarm locate--k.p balenygera d specialist in nature wao wao', ': I am in bomet n i want to join digifarm what can i do?', 'Where is the office of wefarm in Namutumba district?', 'where is a wefarm shop in kilgoris.', ',hellow u guys', 'Hw can u change language in wefarm?', 'WHICH ONE IS YOUR RECOMENTED AGROVET DEALERS IN NANDI COUNTY, TINDERET CONSIT']
#
# --- Meta-cluster 7 ---
# ['how much is a smal incubertor', 'HOW MUCH IS ONE AND WHERE DO YOU STAY', 'thenks,what will be the cost.', 'How much is SIMSIM there?', 'How much is that type?', 'AHAVE 60PAMKINS I WANT TO SELL!', 'How can i get it en at wot price', ', where does madete market located', 'Where can i get vanilla seeds in Mbarara?', 'HOW MUCH ml CAN I USE ONE LITRE OF WATER OF DUDUTHRIN']
#
# --- Meta-cluster 8 ---
# ["Eh'w can i do to boost my henz eggz?", 'am in nakawa Kampala,,, any farmer around to sell eggs to me??', 'BUT y do they eat eggs?', '12000 how much z a tray of eggs', 'what the of breed', 'where can i get a soler powerd brooder and @ how much?', 'What is the importance of eggs in our diet?', 'how can i find an incubator', 'what z de gestation period for the female monkeys??', 'can u pliz connect me to someone who can supply me 1000 tray of eggs every week']
#
# --- Meta-cluster 9 ---
# ['which variety of minji has high yield?.', 'WHICH TYPE OF ACOW IS SOTABLE IN KIMILILI CLAMATE?', 'How much is a packet of gloria', 'how many type of nappes', 'is there market for pilipili hoho', 'wt are best varieties of pla ntation', 'Whare is amarket for pilipili hoho?', 'My ovacado is shedding off leaves. what tecnic should i use to stop it?', 'J Nead Craftade ovacado wear j can get', 'BEST/VARIETIES/TO/GROW/BELOW/ALTITUDE_1600M/2000M/AND/ABOVE.2300M']
#
# --- Meta-cluster 10 ---
# ['for how do i need to harvest my honey', 'hw cn i make my smallchik grow hlpme', 'what is the function s of shade in nursery bed', 'WHERE TO GET SEEDS FOR ONIONRS.', 'Why do same flowers becomes yellow and other falls dawn. what can use 2 prevent such problem.', 'What name is given to sowing of seeds in different places', 'where can I get A I seeds at mogotio Baringo county', 'In This Method Of Breaking Dormancy Called Chitting How Long Does It Take?', 'what are some of the practices r carried on in a nursery bed', 'ALICE ASK .IS THERE CURE 4 ARABICUM SEEDS WHEN THEY START TO ROT.']
#
# --- Meta-cluster 11 ---
# ['Which Is The Best Non Selective I Can Use In My Shamba?', 'when diging shamba which machinery did i use in kabianga', 'E wat cause person fruits leaves yellow?', 'why is greenpaper shed off leaves', 'drying in sun', 'What Name Is Given To The Green Coluring Matter In Leaves And Why It Lost In Some Leaves After Some Time?', 'canes leaves turn yellow,although i topdress it during drought season.What is the problem?', 'I have planted napiagrass bt it turns yellow in colour. what causes', 'Another question is that,, which variety of sukuma week is suitable in soils of Bungoma region ?', 'my sukuma is turning yellow in the shamba even if i maintain spraying what is the problem?']
#
# --- Meta-cluster 12 ---
# ['what is the best pesticides to be used in controlling pests in managu?', 'Which spray can i use', 'what is a spray race ?', 'which metod wil i use to control pest?', 'Tell me the best pestcide used for killing weeds instead of weeding.', 'Which herbicide can I use to spray my vanilla for better yields', 'HOW CAN I HANDLE THESE FARM CHEMICALS THAT TREATS AT THE SAME TIME ITS POISON TO ME?', 'Which chemical is strong in meat and maziwa?', 'How can we control fieldpest', 'E Why is so advantageous to cover your self with overall gumboots aprons and head cover when spraying with herbicide']
#
# --- Meta-cluster 13 ---
# ['is wefarm give out loan realy', 'E. I asked that where can i get an emergence farming loan fram buh no body could reply mhe!', 'How can a farmer get loan', 'DO YOU GIVE LOANS TO FARMERS?', 'how to access loan for farm inputs', 'Which is the recommended capital to start with?', "How much capital does one need to start 'UFUGAJI WA SAMAKI?'", 'how can i get a loan to grow my farm', 'wefarm they have a loan to their farmes?', 'WHAT DID I GET THIS MONEY']
#
# --- Meta-cluster 14 ---
# ['what is debeaking', 'Training of floriculture is where', 'Define the meaning of national integration.', 'tell me steps on how to carry out dehorning,,,i will sponser u with something small', 'What is artificial insermination and can be used', 'WHAT IS DEHORNING', 'WHAT IZ ARTIFICIAL INSERMINATION?', 'define the term castration and equipments used?', 'State the function of acotyledon.', 'Another question says that what is crimate 5ooosh']
#
# --- Meta-cluster 15 ---
# ['How can i treat soil ? When i realise it is affected with wilt.', 'What is the correct medicine for foot rot and mouth disease.', 'what causes mastities', 'What will do to prevent', 'What Is Mastitis?', ';How can i get anti eating medicine?', 'what causes cocidiosis', 'In What Way Would On Prevent Anaplasmosis Deasese', ', What Causes wilting?', 'How Can I Stop Foot & Mouth Diseases']
#
# --- Meta-cluster 16 ---
# ['Reagan asks: Which part of uganda best grows vanilla Reply Q250 followed by your response. optout stop 6333', 'Who Named Uganda The Pearl Of Africa?', 'How many are typies of goet in uganda?', 'Where exactly can find the offices of Wefarm in Uganda?N.B I would like to talk with Wefarm manager.', 'what about in Kenya', 'Kinyua says: in countys in kenya there 47 in kenya which county is best for irrigition give the best one', 'state 3 main language group in kenya', 'Gilbert asks: Asa wefarm do we have some messangers in South Western Uganda Reply Q334 followed by your response. optout stop 6333', 'In kenya,where is agroculture mostly practised?', 'how join illuminatih uganda']
#
# --- Meta-cluster 17 ---
# ['WHICH Z BETTER COWDUNGER OR ARTIFICIAL FERTILIZERS', 'Which type of fertilizer is good in top dressing?', 'is t advisable to mix urea & DAP den use as a top dressing', 'What is the importance of the stick that is driven into the compost heap during preparation', 'Suggestion. Anyone interested in permaculture way of agriculture, pure organic agriculture', 'What Type Of Manure, Organic, Inorganic And How To Incoporate it In The Soil for improvement.', 'HELP.Which one between folia and easy grow has a high nutritional value?', 'Who is in need of new farm fertilizer and weed killer from CANADA PLEASE CONTACT 0779055985', 'Why use urea in topdressing surgane?', 'what is the use of hay?']
#
# --- Meta-cluster 18 ---
# ['give 2 importance of caitivetion ni the farms', 'do we farm give gifts to farmers', 'Where is A We Farm Shop found in central region', 'which type of farming that is suitable for many farmers to use', 'What makes a farmer more confortable in agriculture?', 'what is main difference btw tiny scale and gigantic farmers?ans 0743699880', 'what is meant by the terms vices & stress as used in agriculture', 'How will i get money maker for me to irrigate the farm?', 'What is gneral agriculture?', 'Which methods are used in farming?']
#
# --- Meta-cluster 19 ---
# ['what is the purpose of mulching?', 'Tell Me Da Indications Of Mulching', 'what is the use of land?', 'Ok what is mulching', 'why afarmer decite to use ajembe instate of atractor or ox plough?', 'Why should i mulch my garden', '?What are the advantages of ziro grazing?', 'explain how bush clearing is used as a land reclamation method.', 'HOW MANY DISCS SHOULD BE ON ASTANDARD TRACTOR', ',wat is zero grazing?']
#
# --- Meta-cluster 20 ---
# ['Which instrumentarium is supposed to be carried by inseminator,who use room temperature semen?', 'how long does they take to be ready', 'Wat are signs of pregnant of acow', 'at what temperature does avagina become wet?', 'how long does hos take to give birth?', 'Ayubu asks: hw do u feel wen the penis is inside ur vagina?', 'hw many month do cabege spend to haveste maine spent 4 month still not yet to be haveste tell me want to do', 'hw long does agoat take to produce', 'How a vagina opens', 'I have aquestion how many months do apig take to produce']
#
# --- Meta-cluster 21 ---
# ['WHAT IS HOTICULTURE?', 'what about temperature?', 'What z heat energy?', 'HOW LONG DOES APIG TAKE TO GET ON HEAT AFTER PRODUCING?', 'What is melting?', 'How Long Thus Acow Take Went Is On Heat', 'Dear farmers,l ask what is heat?', 'whow many month did acow take to show sign on heat after delivery', 'what are some of signs oestrus heat!', 'how emay supposed toknow that acow is on heat']
#
# --- Meta-cluster 22 ---
# ['HOW MANY BRANCHES SHOULD YOU LEAVE', 'Am in thika town how can I get them.', 'What rubben say?', 'What about corona in Bomet?', 'I can get for in iganga', 'around which shopping in londiani', 'WHERE TO BUY IN NYERI', 'which is the shortest route to kitale from kapsabet', 'where will i get here in sotik?', 'your have any office in tharaka nithi county?']
#
# --- Meta-cluster 23 ---
# [', MY QUESTION IS THAT , THE RAIN WILL COME ON WHEN?', 'what causes rainfall shortage and scarcity', 'How is mwea climate', 'How long is this season amon mukono district', 'WHAT GET I DO RAIN', "It's dry season please give me some advise for the thing i have to handle during this season", 'Which month in a year recieves alot of rain fall.', ':Does isaga need much rainfall to grow?', ',what Of Global Warming.', 'E Is It Season Time Now Or Not Yet']
#
# --- Meta-cluster 24 ---
# ['State Kinds Of Records Adairy Farmer Would Keep?', 'what is record keeping?', 'What Is Agro§forestry', 'Mention the examples records.', 'What is re-plantation?', 'Define agro-forestry?', 'Dis iz da removal ov excess branches 4rom da garden.', 'Am Request Some Asistance I Want To Start Plantation For Personal Fruit', 'MY PLANTATION IS ALL DRWN. WHAT CAN I DO? IT WAS WIND.', 'WHAT IS FARM RECORDS?']
#
# --- Meta-cluster 25 ---
# ['who were the wefarm champion to day.', 'wefarm! i may kiss penis if you like', 'Why not liable? My phone has problem?', 'Jordan asks: who is the leader of Wefarm.Reply Q13 followed by your response', 'can i get you airtel number', 'E I want to connect somebody on Wefarm, how can i do it?', 'How will i benefit frm this becz i how i can gain 4rm it ok.', 'How will I benefit from Wefarm as new member.', 'how wide is wefarm', 'Who Is De Chairman Of Wefarm?']
#
# --- Meta-cluster 26 ---
# ['YOUNG MOKEYS ARE', 'WHAT IS DEWARMING?', 'how many seasons are in ayear', 'what is deworming?', ',the best timd for deworming morning or evining?', 'At which stage does acow be serviced', ', Which Is The Best Medicine For Deworming?', 'Can u inject catasle to a which is 1 month to deliver', 'Can you deworm acow which is 2 weekr to deliver?', 'Whch Medicine Is The Best For Dewarming']
#
# --- Meta-cluster 27 ---
# ['How can my bro start afarm in the village', 'how can afarmer benefits from this organisation', ',what should i start being to be afarmer?', 'Afarmer says: he wants to know the meaning of acer 19?', 'Osinga asks:how can i start afarm in town. Reply Q77 followed by your response.', 'S afarmer:ety.', 'what does wefarm help you like afarmer after joining it', ',what Are The Benefits Of Quaranteen Measures To Afarmer.', 'What is problem face afarm while practices beehive', 'What about when afarmer started with explanation first befor he/she asky a Quiz?']
